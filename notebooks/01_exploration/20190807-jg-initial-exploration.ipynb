# %%
import pandas as pd
import numpy as np
import censusdata
import json
import math
import pickle
import os
from datetime import datetime
import time

# %% [markdown]
# Functions to save and load `.pkl` files

# %%
def save_pickle(obj, filepath):
    """
    Save an object as a .pkl file, with specified filename (no need to add .pkl suffix).
    The filename must be a string.
    Filepath is already specified as: 'data/' + filename + '.pkl'
    """
    with open(filepath, 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)
        print('Saved', filepath)

# %%
def load_pickle(filepath):
    """
    Load a .pkl file from the `data/` folder.
    The name must be a string.
    Filepath is already specified as: 'data/' + name + '.pkl'
    """
    with open(filepath, 'rb') as f:
        return pickle.load(f)

# %% [markdown]
# Read in Census API key

# %%
with open('../../conf/census_api_secret.json', 'rb') as f:
    data = f.read()
    census_api_secret = json.loads(data)
api_key = census_api_secret['census_api_key']

# %% [markdown]
# #### Build `states_df`, containing state-level identifying info

# %%
states_dict = censusdata.geographies(censusdata.censusgeo([('state', '*')]),
                                       'acs1', 2017, key=api_key)
len(states_dict)
# Out:
# 52

# %%
names = list(states_dict.keys())
ids = [x.geo[0][1] for x in list(states_dict.values())]
state_df = dict(zip(names, ids))
state_df = pd.DataFrame({'state_name': list(state_df.keys()),
                         'census_id': list(state_df.values())
                        })

# %%
with open('../../data/01_raw/states.json', 'rb') as f:
    data = f.read()
    states_json = json.loads(data)

# %%
states_json_df = pd.DataFrame({'state_name': list(states_json.keys()),
                               'state_abbr': list(states_json.values())
                              }) 
state_df = pd.merge(state_df, states_json_df, how='left', on='state_name')
print(state_df.shape)
state_df.head()
# Out:
# (52, 3)
#    state_name census_id state_abbr
# 0     Alabama        01         AL
# 1      Alaska        02         AK
# 2     Arizona        04         AZ
# 3    Arkansas        05         AR
# 4  California        06         CA

# %% [markdown]
# Build `districts_dict` for 1 year (2017)

# %%
districts_dict = censusdata.geographies(censusdata.censusgeo([('congressional district', '*')]),
                                       'acs1', 2017, key=api_key)
len(districts_dict)
# Out:
# 437

# %%
list(districts_dict.keys())[:5]
# Out:
# ['Congressional District 1 (115th Congress), Alabama',
#  'Congressional District 2 (115th Congress), Alabama',
#  'Congressional District 3 (115th Congress), Alabama',
#  'Congressional District 4 (115th Congress), Alabama',
#  'Congressional District 5 (115th Congress), Alabama']

# %%
list(districts_dict.values())[:5]
# Out:
# [censusgeo((('state', '01'), ('congressional district', '01'))),
#  censusgeo((('state', '01'), ('congressional district', '02'))),
#  censusgeo((('state', '01'), ('congressional district', '03'))),
#  censusgeo((('state', '01'), ('congressional district', '04'))),
#  censusgeo((('state', '01'), ('congressional district', '05')))]

# %%
al_01 = list(districts_dict.values())[0]
al_01
# Out:
# censusgeo((('state', '01'), ('congressional district', '01')))

# %%
censusdata.printtable(censusdata.censustable('acs1', 2017, 'B23025'))
# Out:
# Variable     | Table                          | Label                                                    | Type
# -------------------------------------------------------------------------------------------------------------------
# B23025_001E  | EMPLOYMENT STATUS FOR THE POPU | !! Estimate Total                                        | int
# B23025_002E  | EMPLOYMENT STATUS FOR THE POPU | !! !! Estimate Total In labor force                      | int
# B23025_003E  | EMPLOYMENT STATUS FOR THE POPU | !! !! !! Estimate Total In labor force Civilian labor fo | int
# B23025_004E  | EMPLOYMENT STATUS FOR THE POPU | !! !! !! !! Estimate Total In labor force Civilian labor | int
# B23025_005E  | EMPLOYMENT STATUS FOR THE POPU | !! !! !! !! Estimate Total In labor force Civilian labor | int
# B23025_006E  | EMPLOYMENT STATUS FOR THE POPU | !! !! !! Estimate Total In labor force Armed Forces      | int
# B23025_007E  | EMPLOYMENT STATUS FOR THE POPU | !! !! Estimate Total Not in labor force                  | int
# -------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Read in CSV of our Census variables of interest
#
# First go through cleaning process in `Sublime`:
# - find/replace all: "\| int" with ""
# - find/replace all: "\| float" with ""
# - find/replace all: "!! +" with ""
# - find/replace all: "estimate total " with ""
# - fnid/replace all: "estimate "
# - copy/paste into excel; text-to-columns with pipe delimiter
# - add header row: variable, table, label
# - save as csv

# %%
varnames = pd.read_csv('../../data/01_raw/census_variable_list_20190809.csv')
print(varnames.shape)
varnames.tail()
# Out:
# (190, 3)
#         variable                          table  \
# 185  B15002_018E  SEX BY EDUCATIONAL ATTAINMENT
# 186  B15002_032E  SEX BY EDUCATIONAL ATTAINMENT
# 187  B15002_033E  SEX BY EDUCATIONAL ATTAINMENT
# 188  B15002_034E  SEX BY EDUCATIONAL ATTAINMENT
# 189  B15002_035E  SEX BY EDUCATIONAL ATTAINMENT
#
#                                  label
# 185              Male Doctorate degree
# 186           Female Bachelor's degree
# 187             Female Master's degree
# 188  Female Professional school degree
# 189            Female Doctorate degree

# %%
# varnames = pd.read_csv('../../data/01_raw/census_variable_table_crosswalk.csv')
# print(varnames.shape)
# varnames.head()

# %%
varnames['varname_long'] = (varnames.table.str.strip() + '_' 
                + varnames.label.str.strip()).str.replace(' ', '_')
varnames['variable'] = varnames['variable'].str.strip()

# %%
varnames.head()
# Out:
#       variable                             table  \
# 0  B01003_001E   TOTAL POPULATION
# 1  B01001_002E   SEX BY AGE
# 2  B01001_026E   SEX BY AGE
# 3  B01001_004E   SEX BY AGE
# 4  B01001_005E   SEX BY AGE
#
#                                       label                    varname_long
# 0                                                         TOTAL_POPULATION_
# 1    Male                                                   SEX_BY_AGE_Male
# 2    Female                                               SEX_BY_AGE_Female
# 3       Male 5 to 9 years                      SEX_BY_AGE_Male_5_to_9_years
# 4       Male 10 to 14 years                  SEX_BY_AGE_Male_10_to_14_years

# %% [markdown]
# #### Loop over `year` and `district`, passing in the same `varlist` each time
#
# Do you need to first make a call to `censusdata.geographies()` to get districts for each year?

# %%
# varlist stays the same throughout
varlist = list(varnames.variable.str.strip().values)#[:5]
len(varlist)
# Out:
# 190

# %%
new_cols = list(varnames.varname_long.str.strip().values)#[:5]
len(new_cols)
# Out:
# 190

# %% [markdown]
# #### Loop over years

# %% [markdown]
# #### Loop over all states, and districts within each state

# %%
start = datetime.now()
years = [2017, 2016]  # change to all years
census_data = pd.DataFrame()
new_idxs = []
num_of_splits = math.ceil(len(varlist)/25)  # finalize varlist
varlist_split = np.array_split(varlist, num_of_splits)

for year in years:
    print('Year:', year)
    
    year_data = pd.DataFrame()
    for state_abbr in state_df.state_abbr.values[:1]:  # change to all states
        census_id = state_df[state_df.state_abbr == state_abbr]['census_id'].values[0]
        print('state census ID:', census_id)

        districts = censusdata.geographies(censusdata.censusgeo([('state', f'{census_id}'), 
                                                                      ('congressional district', '*')]),
                                          'acs1', year, key=api_key
                                           )
        for district in list(districts.values()):
            print(district)
            state_id = district.geo[0][1]
            district_id = district.geo[1][1]
            state_abbr = state_df[state_df.census_id == state_id]['state_abbr'].values[0]
            colname = state_abbr + '-' + district_id
            print(colname)
            new_idxs.append(colname)

            new_row = pd.DataFrame()
            for varlist in varlist_split:
                new_row = pd.concat([new_row, censusdata.download('acs1', year, district, list(varlist), key=api_key)],
                                    axis=1)
                time.sleep(3)

            year_data = pd.concat([year_data, new_row], sort='False')

    year_data['year'] = year
    census_data = pd.concat([census_data, year_data], sort='False')
    
census_data.index = new_idxs
end = datetime.now()
runtime = end - start
print('Runtime was', runtime.seconds/60, 'minutes')
# Out:
# Year: 2017
# state census ID: 01
# Summary level: 500, state:01> congressional district:01
# AL-01
# Summary level: 500, state:01> congressional district:02
# AL-02
# Summary level: 500, state:01> congressional district:03
# AL-03
# Summary level: 500, state:01> congressional district:04
# AL-04
# Summary level: 500, state:01> congressional district:05
# AL-05
# Summary level: 500, state:01> congressional district:06
# AL-06
# Summary level: 500, state:01> congressional district:07
# AL-07
# Year: 2016
# state census ID: 01
# Summary level: 500, state:01> congressional district:01
# AL-01
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# c:\users\joey\learn-env2\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     602                                                   body=body, headers=headers,
# --> 603                                                   chunked=chunked)
#     604
#
# c:\users\joey\learn-env2\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     386                     # otherwise it looks like a programming error was the cause.
# --> 387                     six.raise_from(e, None)
#     388         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# c:\users\joey\learn-env2\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\users\joey\learn-env2\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#
# c:\users\joey\appdata\local\programs\python\python37-32\Lib\http\client.py in getresponse(self)
#    1335             try:
# -> 1336                 response.begin()
#    1337             except ConnectionError:
#
# c:\users\joey\appdata\local\programs\python\python37-32\Lib\http\client.py in begin(self)
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#
# c:\users\joey\appdata\local\programs\python\python37-32\Lib\http\client.py in _read_status(self)
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#
# c:\users\joey\appdata\local\programs\python\python37-32\Lib\socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# c:\users\joey\learn-env2\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     308             else:
# --> 309                 raise SocketError(str(e))
#     310         except OpenSSL.SSL.ZeroReturnError:
#
# OSError: (10054, 'WSAECONNRESET')
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# c:\users\joey\learn-env2\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# c:\users\joey\learn-env2\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     640             retries = retries.increment(method, url, error=e, _pool=self,
# --> 641                                         _stacktrace=sys.exc_info()[2])
#     642             retries.sleep()
#
# c:\users\joey\learn-env2\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     367             if read is False or not self._is_method_retryable(method):
# --> 368                 raise six.reraise(type(error), error, _stacktrace)
#     369             elif read is not None:
#
# c:\users\joey\learn-env2\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     684         if value.__traceback__ is not tb:
# --> 685             raise value.with_traceback(tb)
#     686         raise value
#
# c:\users\joey\learn-env2\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     602                                                   body=body, headers=headers,
# --> 603                                                   chunked=chunked)
#     604
#
# c:\users\joey\learn-env2\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     386                     # otherwise it looks like a programming error was the cause.
# --> 387                     six.raise_from(e, None)
#     388         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# c:\users\joey\learn-env2\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\users\joey\learn-env2\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#
# c:\users\joey\appdata\local\programs\python\python37-32\Lib\http\client.py in getresponse(self)
#    1335             try:
# -> 1336                 response.begin()
#    1337             except ConnectionError:
#
# c:\users\joey\appdata\local\programs\python\python37-32\Lib\http\client.py in begin(self)
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#
# c:\users\joey\appdata\local\programs\python\python37-32\Lib\http\client.py in _read_status(self)
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#
# c:\users\joey\appdata\local\programs\python\python37-32\Lib\socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# c:\users\joey\learn-env2\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     308             else:
# --> 309                 raise SocketError(str(e))
#     310         except OpenSSL.SSL.ZeroReturnError:
#
# ProtocolError: ('Connection aborted.', OSError("(10054, 'WSAECONNRESET')"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-20-b9d9149144a5> in <module>
#      29             new_row = pd.DataFrame()
#      30             for varlist in varlist_split:
# ---> 31                 new_row = pd.concat([new_row, censusdata.download('acs1', year, district, list(varlist), key=api_key)],
#      32                                     axis=1)
#      33                 time.sleep(3)
#
# c:\users\joey\learn-env2\lib\site-packages\censusdata\download.py in download(src, year, geo, var, key, tabletype, endpt)
#     111         params.update(georequest)
#     112         if key is not None: params.update({'key': key})
# --> 113         data = _download(src + tabletype, year, params, endpt=endpt)
#     114         geodata = data.copy()
#     115         for key in list(geodata.keys()):
#
# c:\users\joey\learn-env2\lib\site-packages\censusdata\download.py in _download(src, year, params, baseurl, endpt)
#      30         else: presrc = ''
#      31         url = baseurl + str(year) + '/' + presrc + src + '?' + '&'.join('='.join(param) for param in params.items())
# ---> 32         r = requests.get(url, timeout=(5, None))
#      33         try:
#      34                 data = r.json()
#
# c:\users\joey\learn-env2\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# c:\users\joey\learn-env2\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# c:\users\joey\learn-env2\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# c:\users\joey\learn-env2\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# c:\users\joey\learn-env2\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', OSError("(10054, 'WSAECONNRESET')"))

# %%
census_data.shape
# Out:
# (0, 0)

# %%
census_data#.head()
# Out:
#        B01001_002E  B01001_004E  B01001_005E  B01001_006E  B01001_007E  \
# AL-01       343769        21687        24958        15014         7992
# AL-02       328474        21345        23661        13221        10058
# AL-03       346742        22945        24502        12872        11286
# AL-04       332923        23278        21585        12877        10731
# AL-05       353533        22442        23188        14620         9218
# AL-06       333957        21334        23391        14584         8743
# AL-07       320498        20911        21470        12724        13906
# AL-01       338759        22527        23756        15335         8611
# AL-02       332477        24514        20603        14324         8992
# AL-03       344900        25641        20409        15045        10236
# AL-04       334330        20462        23088        15482         9401
# AL-05       351008        24319        22888        15655        10211
# AL-06       341170        21957        26083        14297         8340
# AL-07       313408        22629        19170        13628        13109
#
#        B01001_008E  B01001_009E  B01001_010E  B01001_011E  B01001_012E  ...  \
# AL-01         4696         3634        12679        23832        21246  ...
# AL-02         5226         2959        13831        24024        20319  ...
# AL-03         7198         5424        15010        22041        20287  ...
# AL-04         4174         3570        11811        21088        20022  ...
# AL-05         3202         6043        14823        25075        23413  ...
# AL-06         3316         3897        11952        19905        21511  ...
# AL-07         4829         5912        18538        25146        21668  ...
# AL-01         5007         4332        12037        22600        20009  ...
