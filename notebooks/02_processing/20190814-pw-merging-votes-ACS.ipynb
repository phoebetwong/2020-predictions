# %% [markdown]
# ## Cleaning

# %%
import pandas as pd
import numpy as np
import math
import re
from datetime import datetime
import time
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('../../data/01_raw/ACS_ALL.csv')

# %%
df.head()
# Out:
#   Unnamed: 0  B01001_002E  B01001_004E  B01001_005E  B01001_006E  B01001_007E  \
# 0      AL-01       338130        21512        27052        16930        10180
# 1      AL-02       319635        22529        22712        12398         9150
# 2      AL-03       333558        18639        24614        14315        14904
# 3      AL-04       325832        21657        22544        16491         9618
# 4      AL-05       352870        25380        23520        14886        10809
#
#    B01001_008E  B01001_009E  B01001_010E  B01001_011E  ...  B25075_018E  \
# 0         4320         5079        11654        20852  ...      13489.0
# 1         4750         4981        13805        20685  ...       9319.0
# 2         5765         7055        15468        21609  ...       9058.0
# 3         4840         4770         9551        18995  ...       7996.0
# 4         4933         5435        14213        22335  ...      13488.0
#
# ...

# %%
df = df.rename(columns={'Unnamed: 0':'district_id'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3488 entries, 0 to 3487
# Columns: 166 entries, district_id to year
# dtypes: float64(38), int64(127), object(1)
# memory usage: 4.4+ MB

# %%
df['year'] = df.year.apply(str)

# %%
df['yr_district_id'] = df[['year', 'district_id']].apply(lambda x: '-'.join(x), axis=1)

# %%
df.columns = ['district_id',
'Total Male',
'Male 5 to 9 years',
'Male 10 to 14 years',
'Male 15 to 17 years',
'Male 18 and 19 years',
'Male 20 years',
'Male 21 years',
'Male 22 to 24 years',
'Male 25 to 29 years',
'Male 30 to 34 years',
'Male 35 to 39 years',
'Male 40 to 44 years',
'Male 45 to 49 years',
'Male 50 to 54 years',
'Male 55 to 59 years',
'Male 60 and 61 years',
'Male 62 to 64 years',
'Male 65 and 66 years',
'Male 67 to 69 years',
'Male 70 to 74 years',
'Male 75 to 79 years',
'Male 80 to 84 years',
'Male 85 years and over',
'Total Female',
'Female 5 to 9 years',
'Female 10 to 14 years',
'Female 15 to 17 years',
'Female 18 and 19 years',
'Female 20 years',
'Female 21 years',
'Female 22 to 24 years',
'Female 25 to 29 years',
'Female 30 to 34 years',
'Female 35 to 39 years',
'Female 40 to 44 years',
'Female 45 to 49 years',
'Female 50 to 54 years',
'Female 55 to 59 years',
'Female 60 and 61 years',
'Female 62 to 64 years',
'Female 65 and 66 years',
'Female 67 to 69 years',
'Female 70 to 74 years',
'Female 75 to 79 years',
'Female 80 to 84 years',
'Female 85 years and over',
'TOTAL POPULATION',
'White alone',
'Black or African American alone',
'American Indian and Alaska Native',
'Asian alone',
'Native Hawaiian and Other Pacific',
'Some other race alone',
'Two or more races',
'Not Hispanic or Latino',
'Hispanic or Latino',
'Native',
'Native Born in state of residence',
'Native Born in other state',
'Native Born outside the US',
'Foreign born',
'population 25 and over',
'Less than high school graduate',
'High school graduate',
'Some college or associate degree',
'Bachelors degree',
'Graduate or professional degree',
'Same house 1 year ago',
'Moved within same county',
'Moved from different county',
'Moved from different state',
'Moved from abroad',
'Workers 16 and over',
'Public transportation',
'Walked',
'Worked at home',
'Enrolled in school',
'Enrolled in college',
'Enrolled in school Graduate professional',
'Population 25 and over',
'Male Bachelors',
'Male Master',
'Male Professional school',
'Male Doctorate',
'Female Bachelor',
'Female Master',
'Female Professional school',
'Female Doctorate',
'Income below poverty',
'Total Household Income',
'Income Less than 10000',
'Income 10000 to 14999',
'Income 15000 to 19999',
'Income 20000 to 24999',
'Income 25000 to 29999',
'Income 30000 to 34999',
'Income 35000 to 39999',
'Income 40000 to 44999',
'Income 45000 to 49999',
'Income 50000 to 59999',
'Income 60000 to 74999',
'Income 75000 to 99999',
'Income 100000 to 124999',
'Income 125000 to 149999',
'Income 150000 to 199999',
'Income 200000 or more',
'Median household income',
'Income Lowest Quintile',
'Income Second Quintile',
'Income Third Quintile',
'Income Fourth Quintile',
'Income Highest Quintile',
'Income Top 5 Percent',
'Veteran',
'Nonveteran',
'Population 16 and over',
'In labor force',
'Civilian in labor force',
'Civilian Employed',
'Civilian Unemployed',
'In Armed Forces',
'Total not in labor force',
'Fulltime civilian employed 16 and over',
'Male natural resources',
'Male production transportation and material moving',
'Female natural resources',
'Female production transportation and material moving',
'TOTAL HOUSING UNITS',
'Occupied',
'Vacant',
'Occupied Housing units',
'Owner occupied',
'Renter occupied',
'Owner occupied housing units',
'Housing units with a mortgage',
'Housing units without a mortgage',
'renter occupied housing units',
'Median gross rent',
'Total owner occupied housing units',
'Housing Value Below 10000',
'Housing Value 10000 to 14999',
'Housing Value 15000 to 19999',
'Housing Value 20000 to 24999',
'Housing Value 25000 to 29999',
'Housing Value 30000 to 34999',
'Housing Value 35000 to 39999',
'Housing Value 40000 to 49999',
'Housing Value 50000 to 59999',
'Housing Value 60000 to 69999',
'Housing Value 70000 to 79999',
'Housing Value 80000 to 89999',
'Housing Value 90000 to 99999',
'Housing Value 100000 to 124999',
'Housing Value 125000 to 149999',
'Housing Value 150000 to 174999',
'Housing Value 175000 to 199999',
'Housing Value 200000 to 249999',
'Housing Value 250000 to 299999',
'Housing Value 300000 to 399999',
'Housing Value 400000 to 499999',
'Housing Value 500000 to 749999',
'Housing Value 750000 to 999999',
'Housing Value 1000000 to 1499999',
'Median monthly owner costs',
'year',
'yr_district_id']

# %%
df.head()
# Out:
#   district_id  Total Male  Male 5 to 9 years  Male 10 to 14 years  \
# 0       AL-01      338130              21512                27052
# 1       AL-02      319635              22529                22712
# 2       AL-03      333558              18639                24614
# 3       AL-04      325832              21657                22544
# 4       AL-05      352870              25380                23520
#
#    Male 15 to 17 years  Male 18 and 19 years  Male 20 years  Male 21 years  \
# 0                16930                 10180           4320           5079
# 1                12398                  9150           4750           4981
# 2                14315                 14904           5765           7055
# 3                16491                  9618           4840           4770
# 4                14886                 10809           4933           5435
#
#    Male 22 to 24 years  Male 25 to 29 years  ...  \
# 0                11654                20852  ...
# ...

# %% [markdown]
# ## Feature Engineering

# %%
df.sort_values(['district_id', 'year'], inplace=True)

# %%
df['Mpop_share'] = df['Total Male']/df['TOTAL POPULATION']
df['Fpop_share'] = df['Total Female']/df['TOTAL POPULATION']

# %%
df['M75_above'] = df['Male 75 to 79 years'] + \
    df['Male 80 to 84 years'] + df['Male 85 years and over']
df['F75_above'] = df['Female 75 to 79 years'] + \
    df['Female 80 to 84 years'] + df['Female 85 years and over']

df['M60_74'] = df['Male 70 to 74 years'] + df['Male 67 to 69 years'] + \
    df['Male 65 and 66 years'] + \
    df['Male 60 and 61 years'] + df['Male 62 to 64 years']
df['F60_74'] = df['Female 70 to 74 years'] + df['Female 67 to 69 years'] + \
    df['Female 65 and 66 years'] + \
    df['Female 60 and 61 years'] + df['Female 62 to 64 years']

df['M45_59'] = df['Male 45 to 49 years'] + \
    df['Male 50 to 54 years'] + df['Male 55 to 59 years']
df['F45_59'] = df['Female 45 to 49 years'] + \
    df['Female 50 to 54 years'] + df['Female 55 to 59 years']

df['M30_44'] = df['Male 30 to 34 years'] + \
    df['Male 35 to 39 years'] + df['Male 40 to 44 years']
df['F30_44'] = df['Female 30 to 34 years'] + \
    df['Female 35 to 39 years'] + df['Female 40 to 44 years']

df['M18_29'] = df['Male 18 and 19 years'] + df['Male 20 years'] + df['Male 21 years'] + df['Male 22 to 24 years'] + \
    df['Male 25 to 29 years']
df['F18_29'] = df['Female 18 and 19 years'] + df['Female 20 years'] + df['Female 21 years'] + df['Female 22 to 24 years'] + \
    df['Female 25 to 29 years']

df['M18_below'] = df['Total Male'] - df['M18_29'] - \
    df['M30_44'] - df['M45_59'] - df['M60_74'] - df['M75_above']
df['F18_below'] = df['Total Female'] - df['F18_29'] - \
    df['F30_44'] - df['F45_59'] - df['F60_74'] - df['F75_above']

df['M18_above'] = df['Total Male'] - df['M18_below']
df['F18_above'] = df['Total Female'] - df['F18_below']

df['M25_above'] = df['Total Male'] - df['M18_below'] - \
    (df['Male 18 and 19 years'] + df['Male 20 years'] +
     df['Male 21 years'] + df['Male 22 to 24 years'])

df['F25_above'] = df['Total Female'] - df['F18_below'] - \
    (df['Female 18 and 19 years'] + df['Female 20 years'] +
     df['Female 21 years'] + df['Female 22 to 24 years'])

# %%
df['M18_below_share'] = df['M18_below'] / df['Total Male']
df['F18_below_share'] = df['F18_below'] / df['Total Female']
df['18_below_share'] = (df['M18_below'] + df['F18_below'])/df['TOTAL POPULATION']

df['M18_above'] = df['M18_above'] / df['Total Male']
df['F18_above'] = df['F18_above'] / df['Total Female']
df['18_above_share'] = (df['M18_above'] + df['F18_above'])/df['TOTAL POPULATION']

df['M18_29_share'] = df['M18_29'] / df['Total Male']
df['F18_29_share'] = df['F18_29'] / df['Total Female']
df['18_29_share'] = (df['M18_29'] + df['F18_29'])/df['TOTAL POPULATION']

df['M30_44_share'] = df['M30_44'] / df['Total Male']
df['F30_44_share'] = df['F30_44'] / df['Total Female']
df['30_44_share'] = (df['M30_44'] + df['F30_44'])/df['TOTAL POPULATION']

df['M45_59_share'] = df['M45_59'] / df['Total Male']
df['F45_59_share'] = df['F45_59'] / df['Total Female']
df['45_59_share'] = (df['M45_59'] + df['F45_59'])/df['TOTAL POPULATION']

df['M60_74_share'] = df['M60_74'] / df['Total Male']
df['F60_74_share'] = df['F60_74'] / df['Total Female']
df['60_74_share'] = (df['M60_74'] + df['F60_74'])/df['TOTAL POPULATION']

df['M75_above_share'] = df['M75_above'] / df['Total Male']
df['F75_above_share'] = df['F75_above'] / df['Total Female']
df['75_above_share'] = (df['M75_above'] + df['F75_above_share'])/df['TOTAL POPULATION']

# %%
df['white_share'] = df['White alone'] / df['TOTAL POPULATION']
df['black_share'] = df['Black or African American alone'] / df['TOTAL POPULATION']
df['asian_share'] = df['Asian alone'] / df['TOTAL POPULATION']
df['hispanic_share'] = df['Hispanic or Latino'] / df['TOTAL POPULATION']
df['otherrace_share'] = (df['TOTAL POPULATION']-df['White alone']-df['Black or African American alone']-df['Asian alone']) / df['TOTAL POPULATION']
df['native_share'] = df['Native'] / df['TOTAL POPULATION']
df['nativeinstate_share'] = df['Native Born in state of residence'] / df['TOTAL POPULATION']
df['nativeoutofstate_share'] = df['Native Born in other state'] / df['TOTAL POPULATION']
df['foreignborn_share'] = df['Foreign born'] / df['TOTAL POPULATION']

# %%
df['HS_below_share'] = df['Less than high school graduate'] / df['population 25 and over']
df['HS_share'] = df['High school graduate'] / df['population 25 and over']
df['somecollege_share'] = df['Some college or associate degree'] / df['population 25 and over']
df['college_share'] = df['Bachelors degree'] / df['population 25 and over']
df['graddeg_share'] = df['Graduate or professional degree'] / df['population 25 and over']

df['samehouse_share'] = df['Same house 1 year ago'] / df['TOTAL POPULATION']
df['samecounty_share'] = df['Moved within same county'] / df['TOTAL POPULATION']
df['samestate_share'] = df['Moved from different county'] / df['TOTAL POPULATION']
df['diffstate_share'] = df['Moved from different state'] / df['TOTAL POPULATION']
df['liveabroad_share'] = df['Moved from abroad'] / df['TOTAL POPULATION']

# %%
df['ptransport_share'] = df['Public transportation']/df['Workers 16 and over']
df['walktowork_share'] = df['Walked']/df['Workers 16 and over']
df['workathome_share'] = df['Worked at home']/df['Workers 16 and over']

df['inschool_share'] = df['Enrolled in school']/(df['M18_above'] + df['F18_above'])
df['incollege_share'] = df['Enrolled in college']/(df['M18_above'] + df['F18_above'])
df['ingradschool_share'] = df['Enrolled in school Graduate professional']/(df['M18_above'] + df['F18_above'])

# %%
df['M_college_share'] = df['Male Bachelors']/df['M25_above']
df['M_graddeg_share'] = (df['Male Master'] + df['Male Professional school'])/df['M25_above']
df['M_phd_share'] = df['Male Doctorate']/df['M25_above']

df['F_college_share'] = df['Female Bachelor']/df['F25_above']
df['F_graddeg_share'] = (df['Female Master'] + df['Female Professional school'])/df['F25_above']
df['F_phd_share'] = df['Female Doctorate']/df['F25_above']

# %%
df['poverty_share'] = df['Income below poverty'] / df['TOTAL POPULATION']
df['hhinc_10k_less_share'] = df['Income Less than 10000'] / df['Total Household Income']

# %%
df['hhinc_30k_less_share'] = (df['Income Less than 10000'] + df['Income 10000 to 14999']\
                              + df['Income 15000 to 19999'] +
                              df['Income 20000 to 24999'] + df['Income 25000 to 29999'])/\
df['Total Household Income']

# %%
df['hhinc_50k_less_share'] = (df['Income Less than 10000'] + df['Income 10000 to 14999']\
                              + df['Income 15000 to 19999'] +
                              df['Income 20000 to 24999'] + df['Income 25000 to 29999']\
                              + df['Income 30000 to 34999'] + df['Income 35000 to 39999']\
                              + df['Income 40000 to 44999'] +\
                              df['Income 45000 to 49999'])/ df['Total Household Income']

# %%
df['hhinc_75k_more_share'] = (df['Income 75000 to 99999'] + df['Income 100000 to 124999']\
                              + df['Income 125000 to 149999'] + df['Income 150000 to 199999']\
                              + df['Income 200000 or more'])/df['Total Household Income']

# %%
df['hhinc_100k_more_share'] = (df['Income 100000 to 124999']\
                              + df['Income 125000 to 149999'] + df['Income 150000 to 199999']\
                              + df['Income 200000 or more'])/df['Total Household Income']

# %%
df['hhinc_125k_more_share'] = (df['Income 125000 to 149999'] + df['Income 150000 to 199999']\
                              + df['Income 200000 or more'])/df['Total Household Income']

# %%
df['hhinc_150k_more_share'] = (df['Income 150000 to 199999']\
                              + df['Income 200000 or more'])/df['Total Household Income']

# %%
df['hhinc_200k_more_share'] = df['Income 200000 or more']/df['Total Household Income']

# %%
df['veteran'] = df['Veteran']/(df['M18_above'] + df['F18_above'])
df['LFPR'] = df['In labor force']/df['Population 16 and over']
df['Unemp_rate'] = df['Civilian Unemployed']/df['Civilian in labor force']
df['armedforce_share'] = df['In Armed Forces']/df['In labor force']
df['naturalresourcesemp_share'] = (df['Male natural resources']+df['Female natural resources'])\
    / df['Fulltime civilian employed 16 and over']
df['bluecollaremp_share'] = (df['Male production transportation and material moving']
                             + df['Female production transportation and material moving'])\
    / df['Fulltime civilian employed 16 and over']

# %%
df['vacanthousing_share'] = df['Vacant']/ df['TOTAL HOUSING UNITS']
df['renter_share'] = df['Renter occupied']/df['Occupied Housing units']
df['mortgage_share'] = df['Housing units with a mortgage']/df['Owner occupied housing units']

df['housevalue_10k_less_share'] = df['Housing Value Below 10000']/df['Total owner occupied housing units']

df['housevalue_50k_less_share'] = (df['Housing Value Below 10000'] + df['Housing Value 10000 to 14999'] +\
df['Housing Value 15000 to 19999']+df['Housing Value 20000 to 24999']+df['Housing Value 25000 to 29999']\
+df['Housing Value 30000 to 34999']+df['Housing Value 35000 to 39999']+df['Housing Value 40000 to 49999'])\
/df['Total owner occupied housing units']

df['housevalue_100k_less_share'] = (df['Housing Value Below 10000'] + df['Housing Value 10000 to 14999'] +\
df['Housing Value 15000 to 19999']+df['Housing Value 20000 to 24999']+df['Housing Value 25000 to 29999']\
+df['Housing Value 30000 to 34999']+df['Housing Value 35000 to 39999']+df['Housing Value 40000 to 49999']\
+df['Housing Value 50000 to 59999'] + df['Housing Value 60000 to 69999'] +\
df['Housing Value 70000 to 79999']+df['Housing Value 80000 to 89999']+df['Housing Value 90000 to 99999'])\
/df['Total owner occupied housing units']

df['housevalue_300k_more_share'] = (df['Housing Value 300000 to 399999'] + df['Housing Value 400000 to 499999'] +\
df['Housing Value 500000 to 749999']+df['Housing Value 750000 to 999999']+df['Housing Value 1000000 to 1499999'])\
/df['Total owner occupied housing units']

df['housevalue_500k_more_share'] = (df['Housing Value 500000 to 749999']+df['Housing Value 750000 to 999999']\
                                    +df['Housing Value 1000000 to 1499999'])/df['Total owner occupied housing units']

df['housevalue_750k_more_share'] = (df['Housing Value 750000 to 999999']\
                                    +df['Housing Value 1000000 to 1499999'])/df['Total owner occupied housing units']
df['housevalue_1m_more_share'] = df['Housing Value 1000000 to 1499999']/df['Total owner occupied housing units']

# %%
df.head()
# Out:
#      district_id  Total Male  Male 5 to 9 years  Male 10 to 14 years  \
# 7          AK-00      372436              26347                28085
# 443        AK-00      372916              26470                26684
# 879        AK-00      381094              27033                26425
# 1315       AK-00      386404              26989                27265
# 1751       AK-00      385582              27517                25859
#
#       Male 15 to 17 years  Male 18 and 19 years  Male 20 years  Male 21 years  \
# 7                   16477                 10063           6832           7412
# 443                 15011                 10360           7715           7243
# 879                 15899                 12008           5837           7258
# 1315                15762                 13616           7275           5951
# 1751                14719                 11840           6167           8413
#
#       Male 22 to 24 years  Male 25 to 29 years  ...  vacanthousing_share  \
# ...

# %%
varlist = ['Mpop_share','Fpop_share','M18_below_share','F18_below_share','18_below_share',\
           'M18_above','F18_above','18_above_share','M18_29_share','F18_29_share','18_29_share',\
           'M30_44_share','F30_44_share','30_44_share','M45_59_share','F45_59_share','45_59_share',\
           'M60_74_share','F60_74_share','60_74_share','M75_above_share','F75_above_share','75_above_share',\
           'white_share', 'black_share','asian_share','hispanic_share','otherrace_share','native_share',\
           'nativeinstate_share','nativeoutofstate_share','foreignborn_share', 'HS_below_share','HS_share',\
           'somecollege_share','college_share','graddeg_share','samehouse_share','samecounty_share',\
           'samestate_share', 'diffstate_share' ,'liveabroad_share','ptransport_share','walktowork_share',\
           'workathome_share','inschool_share','incollege_share','ingradschool_share','M_college_share',\
           'M_graddeg_share','M_phd_share','F_college_share','F_graddeg_share','F_phd_share','poverty_share',\
           'hhinc_10k_less_share','hhinc_30k_less_share','hhinc_50k_less_share','hhinc_75k_more_share',\
           'hhinc_100k_more_share','hhinc_125k_more_share','hhinc_150k_more_share','hhinc_200k_more_share',\
           'veteran','LFPR','Unemp_rate','armedforce_share','naturalresourcesemp_share','bluecollaremp_share',\
           'vacanthousing_share','renter_share','mortgage_share','housevalue_10k_less_share',\
           'housevalue_50k_less_share','housevalue_100k_less_share','housevalue_300k_more_share',\
           'housevalue_500k_more_share','housevalue_750k_more_share','housevalue_1m_more_share',\
           'Median household income','Income Lowest Quintile','Income Second Quintile','Income Third Quintile',\
           'Income Fourth Quintile','Income Highest Quintile','Income Top 5 Percent','Median gross rent',\
           'Median monthly owner costs']

for var in varlist:
    df[f'L1_{var}']= df[var].shift()
    df[f'L2_{var}']= df[var].shift(2)
    df[f'diff1_{var}'] = df[var] - df[f'L1_{var}']
    df[f'diff2_{var}'] = df[var] - df[f'L2_{var}']

# %%
df.head(50)
# Out:
#      district_id  Total Male  Male 5 to 9 years  Male 10 to 14 years  \
# 7          AK-00      372436              26347                28085
# 443        AK-00      372916              26470                26684
# 879        AK-00      381094              27033                26425
# 1315       AK-00      386404              26989                27265
# 1751       AK-00      385582              27517                25859
# 2187       AK-00      388695              26777                25914
# 2623       AK-00      390573              26386                29741
# 3059       AK-00      385776              27390                25234
# 0          AL-01      338130              21512                27052
# 436        AL-01      334016              25040                22132
# 872        AL-01      336325              22398                24967
# 1308       AL-01      336283              22925                23840
# 1744       AL-01      337140              22404                25905
# ...

# %% [markdown]
# ## These vars need to be standardized by year:

# %% [markdown]
# 'Median household income',
# 'Income Lowest Quintile',
# 'Income Second Quintile',
# 'Income Third Quintile',
# 'Income Fourth Quintile',
# 'Income Highest Quintile',
# 'Income Top 5 Percent',
# 'Median gross rent',
# 'Median monthly owner costs'

# %%
print(df.shape)
df.head()
# Out:
# (3488, 612)
#      district_id  Total Male  Male 5 to 9 years  Male 10 to 14 years  \
# 7          AK-00      372436              26347                28085
# 443        AK-00      372916              26470                26684
# 879        AK-00      381094              27033                26425
# 1315       AK-00      386404              26989                27265
# 1751       AK-00      385582              27517                25859
#
#       Male 15 to 17 years  Male 18 and 19 years  Male 20 years  Male 21 years  \
# 7                   16477                 10063           6832           7412
# 443                 15011                 10360           7715           7243
# 879                 15899                 12008           5837           7258
# 1315                15762                 13616           7275           5951
# 1751                14719                 11840           6167           8413
#
#       Male 22 to 24 years  Male 25 to 29 years  ...  \
# ...

# %% [markdown]
# #### Read in cleaned ACS data with features

# %%
acs_cleaned = pd.read_csv('../../data/02_intermediate/ACS_Features_1218.csv')
print(acs_cleaned.shape)
acs_cleaned.head()
# Out:
# (3488, 614)
#   district_id  year  Total Male  Male 5 to 9 years  Male 10 to 14 years  \
# 0       AK-00  2010      372436              26347                28085
# 1       AK-00  2011      372916              26470                26684
# 2       AK-00  2012      381094              27033                26425
# 3       AK-00  2013      386404              26989                27265
# 4       AK-00  2014      385582              27517                25859
#
#    Male 15 to 17 years  Male 18 and 19 years  Male 20 years  Male 21 years  \
# 0                16477                 10063           6832           7412
# 1                15011                 10360           7715           7243
# 2                15899                 12008           5837           7258
# 3                15762                 13616           7275           5951
# 4                14719                 11840           6167           8413
#
#    Male 22 to 24 years  ...  diff1_Income Top 5 Percent  \
# ...

# %% [markdown]
# Re-order and clean column names

# %%
acs_cleaned = acs_cleaned[[
 'district_id',
 'year',
 'yr_district_id',
 'Total Male',
 'Male 5 to 9 years',
 'Male 10 to 14 years',
 'Male 15 to 17 years',
 'Male 18 and 19 years',
 'Male 20 years',
 'Male 21 years',
 'Male 22 to 24 years',
 'Male 25 to 29 years',
 'Male 30 to 34 years',
 'Male 35 to 39 years',
 'Male 40 to 44 years',
 'Male 45 to 49 years',
 'Male 50 to 54 years',
 'Male 55 to 59 years',
 'Male 60 and 61 years',
 'Male 62 to 64 years',
 'Male 65 and 66 years',
 'Male 67 to 69 years',
 'Male 70 to 74 years',
 'Male 75 to 79 years',
 'Male 80 to 84 years',
 'Male 85 years and over',
 'Total Female',
 'Female 5 to 9 years',
 'Female 10 to 14 years',
 'Female 15 to 17 years',
 'Female 18 and 19 years',
 'Female 20 years',
 'Female 21 years',
 'Female 22 to 24 years',
 'Female 25 to 29 years',
 'Female 30 to 34 years',
 'Female 35 to 39 years',
 'Female 40 to 44 years',
 'Female 45 to 49 years',
 'Female 50 to 54 years',
 'Female 55 to 59 years',
 'Female 60 and 61 years',
 'Female 62 to 64 years',
 'Female 65 and 66 years',
 'Female 67 to 69 years',
 'Female 70 to 74 years',
 'Female 75 to 79 years',
 'Female 80 to 84 years',
 'Female 85 years and over',
 'TOTAL POPULATION',
 'White alone',
 'Black or African American alone',
 'American Indian and Alaska Native',
 'Asian alone',
 'Native Hawaiian and Other Pacific',
 'Some other race alone',
 'Two or more races',
 'Not Hispanic or Latino',
 'Hispanic or Latino',
 'Native',
 'Native Born in state of residence',
 'Native Born in other state',
 'Native Born outside the US',
 'Foreign born',
 'population 25 and over',
 'Less than high school graduate',
 'High school graduate',
 'Some college or associate degree',
 'Bachelors degree',
 'Graduate or professional degree',
 'Same house 1 year ago',
 'Moved within same county',
 'Moved from different county',
 'Moved from different state',
 'Moved from abroad',
 'Workers 16 and over',
 'Public transportation',
 'Walked',
 'Worked at home',
 'Enrolled in school',
 'Enrolled in college',
 'Enrolled in school Graduate professional',
 'Population 25 and over',
 'Male Bachelors',
 'Male Master',
 'Male Professional school',
 'Male Doctorate',
 'Female Bachelor',
 'Female Master',
 'Female Professional school',
 'Female Doctorate',
 'Income below poverty',
 'Total Household Income',
 'Income Less than 10000',
 'Income 10000 to 14999',
 'Income 15000 to 19999',
 'Income 20000 to 24999',
 'Income 25000 to 29999',
 'Income 30000 to 34999',
 'Income 35000 to 39999',
 'Income 40000 to 44999',
 'Income 45000 to 49999',
 'Income 50000 to 59999',
 'Income 60000 to 74999',
 'Income 75000 to 99999',
 'Income 100000 to 124999',
 'Income 125000 to 149999',
 'Income 150000 to 199999',
 'Income 200000 or more',
 'Median household income',
 'Income Lowest Quintile',
 'Income Second Quintile',
 'Income Third Quintile',
 'Income Fourth Quintile',
 'Income Highest Quintile',
 'Income Top 5 Percent',
 'Veteran',
 'Nonveteran',
 'Population 16 and over',
 'In labor force',
 'Civilian in labor force',
 'Civilian Employed',
 'Civilian Unemployed',
 'In Armed Forces',
 'Total not in labor force',
 'Fulltime civilian employed 16 and over',
 'Male natural resources',
 'Male production transportation and material moving',
 'Female natural resources',
 'Female production transportation and material moving',
 'TOTAL HOUSING UNITS',
 'Occupied',
 'Vacant',
 'Occupied Housing units',
 'Owner occupied',
 'Renter occupied',
 'Owner occupied housing units',
 'Housing units with a mortgage',
 'Housing units without a mortgage',
 'renter occupied housing units',
 'Median gross rent',
 'Total owner occupied housing units',
 'Housing Value Below 10000',
 'Housing Value 10000 to 14999',
 'Housing Value 15000 to 19999',
 'Housing Value 20000 to 24999',
 'Housing Value 25000 to 29999',
 'Housing Value 30000 to 34999',
 'Housing Value 35000 to 39999',
 'Housing Value 40000 to 49999',
 'Housing Value 50000 to 59999',
 'Housing Value 60000 to 69999',
 'Housing Value 70000 to 79999',
 'Housing Value 80000 to 89999',
 'Housing Value 90000 to 99999',
 'Housing Value 100000 to 124999',
 'Housing Value 125000 to 149999',
 'Housing Value 150000 to 174999',
 'Housing Value 175000 to 199999',
 'Housing Value 200000 to 249999',
 'Housing Value 250000 to 299999',
 'Housing Value 300000 to 399999',
 'Housing Value 400000 to 499999',
 'Housing Value 500000 to 749999',
 'Housing Value 750000 to 999999',
 'Housing Value 1000000 to 1499999',
 'Median monthly owner costs',
 'malepop_share',
 'femalepop_share',
 'M75_above',
 'F75_above',
 'M60_74',
 'F60_74',
 'M45_59',
 'F45_59',
 'M30_44',
 'F30_44',
 'M18_29',
 'F18_29',
 'M18_below',
 'F18_below',
 'M18_below_share',
 'F18_below_share',
 '18_below_share',
 'M18_29_share',
 'F18_29_share',
 '18_29_share',
 'M30_44_share',
 'F30_44_share',
 '30_44_share',
 'M45_59_share',
 'F45_59_share',
 '45_59_share',
 'M60_74_share',
 'F60_74_share',
 '60_74_share',
 'M75_above_share',
 'F75_above_share',
 '75_above_share',
 'white_share',
 'black_share',
 'asian_share',
 'hispanic_share',
 'otherrace_share',
 'native_share',
 'nativeinstate_share',
 'nativeoutofstate_share',
 'foreignborn_share',
 'HS_below_share',
 'HS_share',
 'somecollege_share',
 'college_share',
 'graddeg_share',
 'samehouse_share',
 'samecounty_share',
 'samestate_share',
 'diffstate_share',
 'liveabroad_share',
 'M18_above',
 'F18_above',
 '18_above_share',
 'ptransport_share',
 'walktowork_share',
 'workathome_share',
 'inschool_share',
 'incollege_share',
 'ingradschool_share',
 'M25_above',
 'F25_above',
 'M_college_share',
 'M_graddeg_share',
 'M_phd_share',
 'F_college_share',
 'F_graddeg_share',
 'F_phd_share',
 'poverty_share',
 'hhinc_10k_less_share',
 'hhinc_30k_less_share',
 'hhinc_50k_less_share',
 'hhinc_75k_more_share',
 'hhinc_100k_more_share',
 'hhinc_125k_more_share',
 'hhinc_150k_more_share',
 'hhinc_200k_more_share',
 'veteran',
 'LFPR',
 'Unemp_rate',
 'armedforce_share',
 'naturalresourcesemp_share',
 'bluecollaremp_share',
 'vacanthousing_share',
 'renter_share',
 'mortgage_share',
 'housevalue_10k_less_share',
 'housevalue_50k_less_share',
 'housevalue_100k_less_share',
 'housevalue_300k_more_share',
 'housevalue_500k_more_share',
 'housevalue_750k_more_share',
 'housevalue_1m_more_share',
 'Mpop_share',
 'Fpop_share',
 'L1_Mpop_share',
 'L2_Mpop_share',
 'L1_Fpop_share',
 'L2_Fpop_share',
 'diff1_Mpop_share',
 'diff2_Mpop_share',
 'diff1_Fpop_share',
 'diff2_Fpop_share',
 'L1_M18_below_share',
 'L2_M18_below_share',
 'diff1_M18_below_share',
 'diff2_M18_below_share',
 'L1_F18_below_share',
 'L2_F18_below_share',
 'diff1_F18_below_share',
 'diff2_F18_below_share',
 'L1_18_below_share',
 'L2_18_below_share',
 'diff1_18_below_share',
 'diff2_18_below_share',
 'L1_M18_above',
 'L2_M18_above',
 'diff1_M18_above',
 'diff2_M18_above',
 'L1_F18_above',
 'L2_F18_above',
 'diff1_F18_above',
 'diff2_F18_above',
 'L1_18_above_share',
 'L2_18_above_share',
 'diff1_18_above_share',
 'diff2_18_above_share',
 'L1_M18_29_share',
 'L2_M18_29_share',
 'diff1_M18_29_share',
 'diff2_M18_29_share',
 'L1_F18_29_share',
 'L2_F18_29_share',
 'diff1_F18_29_share',
 'diff2_F18_29_share',
 'L1_18_29_share',
 'L2_18_29_share',
 'diff1_18_29_share',
 'diff2_18_29_share',
 'L1_M30_44_share',
 'L2_M30_44_share',
 'diff1_M30_44_share',
 'diff2_M30_44_share',
 'L1_F30_44_share',
 'L2_F30_44_share',
 'diff1_F30_44_share',
 'diff2_F30_44_share',
 'L1_30_44_share',
 'L2_30_44_share',
 'diff1_30_44_share',
 'diff2_30_44_share',
 'L1_M45_59_share',
 'L2_M45_59_share',
 'diff1_M45_59_share',
 'diff2_M45_59_share',
 'L1_F45_59_share',
 'L2_F45_59_share',
 'diff1_F45_59_share',
 'diff2_F45_59_share',
 'L1_45_59_share',
 'L2_45_59_share',
 'diff1_45_59_share',
 'diff2_45_59_share',
 'L1_M60_74_share',
 'L2_M60_74_share',
 'diff1_M60_74_share',
 'diff2_M60_74_share',
 'L1_F60_74_share',
 'L2_F60_74_share',
 'diff1_F60_74_share',
 'diff2_F60_74_share',
 'L1_60_74_share',
 'L2_60_74_share',
 'diff1_60_74_share',
 'diff2_60_74_share',
 'L1_M75_above_share',
 'L2_M75_above_share',
 'diff1_M75_above_share',
 'diff2_M75_above_share',
 'L1_F75_above_share',
 'L2_F75_above_share',
 'diff1_F75_above_share',
 'diff2_F75_above_share',
 'L1_75_above_share',
 'L2_75_above_share',
 'diff1_75_above_share',
 'diff2_75_above_share',
 'L1_white_share',
 'L2_white_share',
 'diff1_white_share',
 'diff2_white_share',
 'L1_black_share',
 'L2_black_share',
 'diff1_black_share',
 'diff2_black_share',
 'L1_asian_share',
 'L2_asian_share',
 'diff1_asian_share',
 'diff2_asian_share',
 'L1_hispanic_share',
 'L2_hispanic_share',
 'diff1_hispanic_share',
 'diff2_hispanic_share',
 'L1_otherrace_share',
 'L2_otherrace_share',
 'diff1_otherrace_share',
 'diff2_otherrace_share',
 'L1_native_share',
 'L2_native_share',
 'diff1_native_share',
 'diff2_native_share',
 'L1_nativeinstate_share',
 'L2_nativeinstate_share',
 'diff1_nativeinstate_share',
 'diff2_nativeinstate_share',
 'L1_nativeoutofstate_share',
 'L2_nativeoutofstate_share',
 'diff1_nativeoutofstate_share',
 'diff2_nativeoutofstate_share',
 'L1_foreignborn_share',
 'L2_foreignborn_share',
 'diff1_foreignborn_share',
 'diff2_foreignborn_share',
 'L1_HS_below_share',
 'L2_HS_below_share',
 'diff1_HS_below_share',
 'diff2_HS_below_share',
 'L1_HS_share',
 'L2_HS_share',
 'diff1_HS_share',
 'diff2_HS_share',
 'L1_somecollege_share',
 'L2_somecollege_share',
 'diff1_somecollege_share',
 'diff2_somecollege_share',
 'L1_college_share',
 'L2_college_share',
 'diff1_college_share',
 'diff2_college_share',
 'L1_graddeg_share',
 'L2_graddeg_share',
 'diff1_graddeg_share',
 'diff2_graddeg_share',
 'L1_samehouse_share',
 'L2_samehouse_share',
 'diff1_samehouse_share',
 'diff2_samehouse_share',
 'L1_samecounty_share',
 'L2_samecounty_share',
 'diff1_samecounty_share',
 'diff2_samecounty_share',
 'L1_samestate_share',
 'L2_samestate_share',
 'diff1_samestate_share',
 'diff2_samestate_share',
 'L1_diffstate_share',
 'L2_diffstate_share',
 'diff1_diffstate_share',
 'diff2_diffstate_share',
 'L1_liveabroad_share',
 'L2_liveabroad_share',
 'diff1_liveabroad_share',
 'diff2_liveabroad_share',
 'L1_ptransport_share',
 'L2_ptransport_share',
 'diff1_ptransport_share',
 'diff2_ptransport_share',
 'L1_walktowork_share',
 'L2_walktowork_share',
 'diff1_walktowork_share',
 'diff2_walktowork_share',
 'L1_workathome_share',
 'L2_workathome_share',
 'diff1_workathome_share',
 'diff2_workathome_share',
 'L1_inschool_share',
 'L2_inschool_share',
 'diff1_inschool_share',
 'diff2_inschool_share',
 'L1_incollege_share',
 'L2_incollege_share',
 'diff1_incollege_share',
 'diff2_incollege_share',
 'L1_ingradschool_share',
 'L2_ingradschool_share',
 'diff1_ingradschool_share',
 'diff2_ingradschool_share',
 'L1_M_college_share',
 'L2_M_college_share',
 'diff1_M_college_share',
 'diff2_M_college_share',
 'L1_M_graddeg_share',
 'L2_M_graddeg_share',
 'diff1_M_graddeg_share',
 'diff2_M_graddeg_share',
 'L1_M_phd_share',
 'L2_M_phd_share',
 'diff1_M_phd_share',
 'diff2_M_phd_share',
 'L1_F_college_share',
 'L2_F_college_share',
 'diff1_F_college_share',
 'diff2_F_college_share',
 'L1_F_graddeg_share',
 'L2_F_graddeg_share',
 'diff1_F_graddeg_share',
 'diff2_F_graddeg_share',
 'L1_F_phd_share',
 'L2_F_phd_share',
 'diff1_F_phd_share',
 'diff2_F_phd_share',
 'L1_poverty_share',
 'L2_poverty_share',
 'diff1_poverty_share',
 'diff2_poverty_share',
 'L1_hhinc_10k_less_share',
 'L2_hhinc_10k_less_share',
 'diff1_hhinc_10k_less_share',
 'diff2_hhinc_10k_less_share',
 'L1_hhinc_30k_less_share',
 'L2_hhinc_30k_less_share',
 'diff1_hhinc_30k_less_share',
 'diff2_hhinc_30k_less_share',
 'L1_hhinc_50k_less_share',
 'L2_hhinc_50k_less_share',
 'diff1_hhinc_50k_less_share',
 'diff2_hhinc_50k_less_share',
 'L1_hhinc_75k_more_share',
 'L2_hhinc_75k_more_share',
 'diff1_hhinc_75k_more_share',
 'diff2_hhinc_75k_more_share',
 'L1_hhinc_100k_more_share',
 'L2_hhinc_100k_more_share',
 'diff1_hhinc_100k_more_share',
 'diff2_hhinc_100k_more_share',
 'L1_hhinc_125k_more_share',
 'L2_hhinc_125k_more_share',
 'diff1_hhinc_125k_more_share',
 'diff2_hhinc_125k_more_share',
 'L1_hhinc_150k_more_share',
 'L2_hhinc_150k_more_share',
 'diff1_hhinc_150k_more_share',
 'diff2_hhinc_150k_more_share',
 'L1_hhinc_200k_more_share',
 'L2_hhinc_200k_more_share',
 'diff1_hhinc_200k_more_share',
 'diff2_hhinc_200k_more_share',
 'L1_veteran',
 'L2_veteran',
 'diff1_veteran',
 'diff2_veteran',
 'L1_LFPR',
 'L2_LFPR',
 'diff1_LFPR',
 'diff2_LFPR',
 'L1_Unemp_rate',
 'L2_Unemp_rate',
 'diff1_Unemp_rate',
 'diff2_Unemp_rate',
 'L1_armedforce_share',
 'L2_armedforce_share',
 'diff1_armedforce_share',
 'diff2_armedforce_share',
 'L1_naturalresourcesemp_share',
 'L2_naturalresourcesemp_share',
 'diff1_naturalresourcesemp_share',
 'diff2_naturalresourcesemp_share',
 'L1_bluecollaremp_share',
 'L2_bluecollaremp_share',
 'diff1_bluecollaremp_share',
 'diff2_bluecollaremp_share',
 'L1_vacanthousing_share',
 'L2_vacanthousing_share',
 'diff1_vacanthousing_share',
 'diff2_vacanthousing_share',
 'L1_renter_share',
 'L2_renter_share',
 'diff1_renter_share',
 'diff2_renter_share',
 'L1_mortgage_share',
 'L2_mortgage_share',
 'diff1_mortgage_share',
 'diff2_mortgage_share',
 'L1_housevalue_10k_less_share',
 'L2_housevalue_10k_less_share',
 'diff1_housevalue_10k_less_share',
 'diff2_housevalue_10k_less_share',
 'L1_housevalue_50k_less_share',
 'L2_housevalue_50k_less_share',
 'diff1_housevalue_50k_less_share',
 'diff2_housevalue_50k_less_share',
 'L1_housevalue_100k_less_share',
 'L2_housevalue_100k_less_share',
 'diff1_housevalue_100k_less_share',
 'diff2_housevalue_100k_less_share',
 'L1_housevalue_300k_more_share',
 'L2_housevalue_300k_more_share',
 'diff1_housevalue_300k_more_share',
 'diff2_housevalue_300k_more_share',
 'L1_housevalue_500k_more_share',
 'L2_housevalue_500k_more_share',
 'diff1_housevalue_500k_more_share',
 'diff2_housevalue_500k_more_share',
 'L1_housevalue_750k_more_share',
 'L2_housevalue_750k_more_share',
 'diff1_housevalue_750k_more_share',
 'diff2_housevalue_750k_more_share',
 'L1_housevalue_1m_more_share',
 'L2_housevalue_1m_more_share',
 'diff1_housevalue_1m_more_share',
 'diff2_housevalue_1m_more_share',
 'L1_Median household income',
 'L2_Median household income',
 'diff1_Median household income',
 'diff2_Median household income',
 'L1_Income Lowest Quintile',
 'L2_Income Lowest Quintile',
 'diff1_Income Lowest Quintile',
 'diff2_Income Lowest Quintile',
 'L1_Income Second Quintile',
 'L2_Income Second Quintile',
 'diff1_Income Second Quintile',
 'diff2_Income Second Quintile',
 'L1_Income Third Quintile',
 'L2_Income Third Quintile',
 'diff1_Income Third Quintile',
 'diff2_Income Third Quintile',
 'L1_Income Fourth Quintile',
 'L2_Income Fourth Quintile',
 'diff1_Income Fourth Quintile',
 'diff2_Income Fourth Quintile',
 'L1_Income Highest Quintile',
 'L2_Income Highest Quintile',
 'diff1_Income Highest Quintile',
 'diff2_Income Highest Quintile',
 'L1_Income Top 5 Percent',
 'L2_Income Top 5 Percent',
 'diff1_Income Top 5 Percent',
 'diff2_Income Top 5 Percent',
 'L1_Median gross rent',
 'L2_Median gross rent',
 'diff1_Median gross rent',
 'diff2_Median gross rent',
 'L1_Median monthly owner costs',
 'L2_Median monthly owner costs',
 'diff1_Median monthly owner costs',
 'diff2_Median monthly owner costs'
]]

# %%
acs_cleaned.columns = acs_cleaned.columns.str.replace(' ', '_').str.lower()

# %%
acs_cleaned.shape
# Out:
# (3488, 614)

# %% [markdown]
# Split `acs_cleaned` by year (for the 9 variables that need to be standardized by year)

# %%
numeric_columns = acs_cleaned[[
 'year',
#  'yr_district_id',
 'median_household_income',
 'income_lowest_quintile',
 'income_second_quintile',
 'income_third_quintile',
 'income_fourth_quintile',
 'income_highest_quintile',
 'income_top_5_percent',
 'median_gross_rent',
 'median_monthly_owner_costs']]

# %%
print(numeric_columns.shape)
numeric_columns.head(20)
# Out:
# (3488, 10)
#     year  median_household_income  income_lowest_quintile  \
# 0   2010                    64576                   16104
# 1   2011                    67825                   17365
# 2   2012                    67712                   16888
# 3   2013                    72237                   18887
# 4   2014                    71583                   17950
# 5   2015                    73355                   18458
# 6   2016                    76440                   19349
# 7   2017                    73181                   18086
# 8   2010                    41172                    8233
# 9   2011                    43144                    9379
# 10  2012                    41450                    8354
# 11  2013                    42309                    8831
# 12  2014                    44030                    9483
# 13  2015                    44535                    8988
# 14  2016                    47083                    9274
# ...

# %% [markdown]
# Look through years, building a dataframe of scaled data (retain indices to join with `acs_cleaned`)

# %%
data = numeric_columns.copy()
subset = data[data.year == 2010]
subset = subset.drop('year', axis=1)
indices = subset.index

scaler = StandardScaler()
subset_scaled = pd.DataFrame(scaler.fit_transform(subset),
                                           columns=subset.columns + '_scaled')

# %%
indices
# Out:
# Int64Index([   0,    8,   16,   24,   32,   40,   48,   56,   64,   72,
#             ...
#             3408, 3416, 3424, 3432, 3440, 3448, 3456, 3464, 3472, 3480],
#            dtype='int64', length=436)

# %%
scaled_data = pd.DataFrame()
data = numeric_columns.copy()

for yr in range(2010, 2018):  # CHANGE RANGE
    print(yr)
    subset = data[data.year == yr]
    subset = subset.drop('year', axis=1)
    indices = subset.index
    
    scaler = StandardScaler()
    subset_scaled = pd.DataFrame(scaler.fit_transform(subset),
                                               columns=subset.columns + '_scaled')
    subset_scaled.index = indices
    scaled_data = pd.concat([scaled_data, subset_scaled], sort=False)
# Out:
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017

# %%
scaled_data.shape
# Out:
# (3488, 9)

# %%
scaled_data.head()
# Out:
#     median_household_income_scaled  income_lowest_quintile_scaled  \
# 0                         0.982807                       1.088494
# 8                        -0.761755                      -1.078711
# 16                       -0.806852                      -0.808878
# 24                       -1.188130                      -1.272276
# 32                       -1.093985                      -0.795661
#
#     income_second_quintile_scaled  income_third_quintile_scaled  \
# 0                        1.037140                      0.989846
# 8                       -0.859282                     -0.760964
# 16                      -0.882191                     -0.816896
# 24                      -1.275011                     -1.182939
# 32                      -1.033714                     -1.123070
#
#     income_fourth_quintile_scaled  income_highest_quintile_scaled  \
# 0                        0.966714                        0.431134
# ...

# %% [markdown]
# ### Merge `scaled_data` with `acs_cleaned`

# %%
print(acs_cleaned.shape)
acs_cleaned.head()
# Out:
# (3488, 614)
#   district_id  year yr_district_id  total_male  male_5_to_9_years  \
# 0       AK-00  2010     2010-AK-00      372436              26347
# 1       AK-00  2011     2011-AK-00      372916              26470
# 2       AK-00  2012     2012-AK-00      381094              27033
# 3       AK-00  2013     2013-AK-00      386404              26989
# 4       AK-00  2014     2014-AK-00      385582              27517
#
#    male_10_to_14_years  male_15_to_17_years  male_18_and_19_years  \
# 0                28085                16477                 10063
# 1                26684                15011                 10360
# 2                26425                15899                 12008
# 3                27265                15762                 13616
# 4                25859                14719                 11840
#
#    male_20_years  male_21_years  ...  diff1_income_top_5_percent  \
# 0           6832           7412  ...                         NaN
# ...

# %%
acs_cleaned_w_scaled_cols = pd.merge(acs_cleaned, 
                                     scaled_data,
                                     how='left', 
                                     left_index=True, 
                                     right_index=True)
acs_cleaned_w_scaled_cols.shape
# Out:
# (3488, 623)

# %%
acs_cleaned_w_scaled_cols.head()
# Out:
#   district_id  year yr_district_id  total_male  male_5_to_9_years  \
# 0       AK-00  2010     2010-AK-00      372436              26347
# 1       AK-00  2011     2011-AK-00      372916              26470
# 2       AK-00  2012     2012-AK-00      381094              27033
# 3       AK-00  2013     2013-AK-00      386404              26989
# 4       AK-00  2014     2014-AK-00      385582              27517
#
#    male_10_to_14_years  male_15_to_17_years  male_18_and_19_years  \
# 0                28085                16477                 10063
# 1                26684                15011                 10360
# 2                26425                15899                 12008
# 3                27265                15762                 13616
# 4                25859                14719                 11840
#
#    male_20_years  male_21_years  ...  diff2_median_monthly_owner_costs  \
# 0           6832           7412  ...                               NaN
# ...

# %% [markdown]
# #### Model 1 w/ 2017 substituted for 2018 ACS features

# %%
acs_cleaned_w_scaled_cols['year_merge'] = acs_cleaned_w_scaled_cols['year'].replace(2017,2018)

# %%
acs_cleaned_w_scaled_cols['year_merge'].value_counts()
# Out:
# 2011    872
# 2017    436
# 2015    436
# 2013    436
# 2016    436
# 2014    436
# 2010    436
# Name: year_merge, dtype: int64

# %%
acs_cleaned_w_scaled_cols['year_merge'] = acs_cleaned_w_scaled_cols.year_merge.apply(str)

# %%
acs_cleaned_w_scaled_cols['yr_district_id'] = acs_cleaned_w_scaled_cols[['year_merge', 'district_id']].apply(lambda x: '-'.join(x), axis=1)

# %%
acs_cleaned_w_scaled_cols.head(50)
# Out:
#    district_id  year yr_district_id  total_male  male_5_to_9_years  \
# 0        AK-00  2010     2010-AK-00      372436              26347
# 1        AK-00  2011     2011-AK-00      372916              26470
# 2        AK-00  2012     2012-AK-00      381094              27033
# 3        AK-00  2013     2013-AK-00      386404              26989
# 4        AK-00  2014     2014-AK-00      385582              27517
# 5        AK-00  2015     2015-AK-00      388695              26777
# 6        AK-00  2016     2016-AK-00      390573              26386
# 7        AK-00  2017     2018-AK-00      385776              27390
# 8        AL-01  2010     2010-AL-01      338130              21512
# 9        AL-01  2011     2011-AL-01      334016              25040
# 10       AL-01  2012     2012-AL-01      336325              22398
# 11       AL-01  2013     2013-AL-01      336283              22925
# 12       AL-01  2014     2014-AL-01      337140              22404
# ...

# %% [markdown]
# #### Model 2 w/ one year lag ACS features

# %%
acs_cleaned_w_scaled_cols['year_merge_2'] = 0
acs_cleaned_w_scaled_cols.loc[acs_cleaned_w_scaled_cols["year"] == 2011, 'year_merge_2'] = 2012
acs_cleaned_w_scaled_cols.loc[acs_cleaned_w_scaled_cols["year"] == 2013, 'year_merge_2'] = 2014
acs_cleaned_w_scaled_cols.loc[acs_cleaned_w_scaled_cols["year"] == 2015, 'year_merge_2'] = 2016
acs_cleaned_w_scaled_cols.loc[acs_cleaned_w_scaled_cols["year"] == 2017, 'year_merge_2'] = 2018

# %%
acs_cleaned_w_scaled_cols['year_merge_2'] = acs_cleaned_w_scaled_cols.year_merge_2.apply(str)

# %%
acs_cleaned_w_scaled_cols['yr_district_id'] = acs_cleaned_w_scaled_cols[['year_merge_2', 'district_id']].apply(lambda x: '-'.join(x), axis=1)

# %%
acs_cleaned_w_scaled_cols
# Out:
#      district_id  year yr_district_id  total_male  male_5_to_9_years  \
# 0          AK-00  2010        0-AK-00      372436              26347
# 1          AK-00  2011     2012-AK-00      372916              26470
# 2          AK-00  2012        0-AK-00      381094              27033
# 3          AK-00  2013     2014-AK-00      386404              26989
# 4          AK-00  2014        0-AK-00      385582              27517
# 5          AK-00  2015     2016-AK-00      388695              26777
# 6          AK-00  2016        0-AK-00      390573              26386
# 7          AK-00  2017     2018-AK-00      385776              27390
# 8          AL-01  2010        0-AL-01      338130              21512
# 9          AL-01  2011     2012-AL-01      334016              25040
# 10         AL-01  2012        0-AL-01      336325              22398
# 11         AL-01  2013     2014-AL-01      336283              22925
# 12         AL-01  2014        0-AL-01      337140              22404
# ...

# %%
acs_cleaned_w_scaled_cols.to_csv('../../data/02_intermediate/ACS_final_L1years.csv')

# %% [markdown]
# #### Read in election history data, merge with `acs_cleaned_w_scaled_cols`

# %%
election_data = pd.read_csv('../../data/02_intermediate/HouseVotesFeatures_12_18_incumbents.csv')
print(election_data.shape)
election_data.head()
# Out:
# (1740, 75)
#    Unnamed: 0 yr_district_id  winner_votes  totalvotes  year    state  \
# 0        7813     2012-AK-00        185296      289804  2012   Alaska
# 1        8248     2014-AK-00        142572      279741  2014   Alaska
# 2        8683     2016-AK-00        155088      308198  2016   Alaska
# 3        9118     2018-AK-00        149779      282166  2018   Alaska
# 4        7814     2012-AL-01        196374      200676  2012  Alabama
#
#      winner winner_party  writein district_id  ...  dem_L3_voteshare  \
# 0  DonYoung   republican    False       AK-00  ...          0.347010
# 1  DonYoung   republican    False       AK-00  ...          0.333651
# 2  DonYoung   republican    False       AK-00  ...          0.352013
# 3  DonYoung   republican    False       AK-00  ...          0.411621
# 4  JoBonner   republican    False       AL-01  ...          0.000000
#
#    dem_L2_voteshare  dem_L1_voteshare  target  top_dem_votes  \
# ...

# %%
election_data.drop(['Unnamed: 0'], axis=1, inplace=True)
election_data.shape
# Out:
# (1740, 74)

# %%
election_data.to_csv('../../data/02_intermediate/HouseVotes.csv', index=False)

# %%
acs_cleaned_w_scaled_cols.shape
# Out:
# (3488, 625)

# %%
acs_election_merged = pd.merge(election_data,
                                 acs_cleaned_w_scaled_cols,
                                 how='left',
                                 on='yr_district_id'
                                )
acs_election_merged.shape
# Out:
# (1740, 698)

# %%
acs_election_merged.head()
# Out:
#   yr_district_id  winner_votes  totalvotes  year_x    state    winner  \
# 0     2012-AK-00        185296      289804    2012   Alaska  DonYoung
# 1     2014-AK-00        142572      279741    2014   Alaska  DonYoung
# 2     2016-AK-00        155088      308198    2016   Alaska  DonYoung
# 3     2018-AK-00        149779      282166    2018   Alaska  DonYoung
# 4     2012-AL-01        196374      200676    2012  Alabama  JoBonner
#
#   winner_party  writein district_id_x  winner_voteshare  ...  \
# 0   republican    False         AK-00          0.639384  ...
# 1   republican    False         AK-00          0.509657  ...
# 2   republican    False         AK-00          0.503209  ...
# 3   republican    False         AK-00          0.530819  ...
# 4   republican    False         AL-01          0.978562  ...
#
#    income_lowest_quintile_scaled  income_second_quintile_scaled  \
# 0                       1.498107                       1.359730
# ...

# %%
acs_election_merged.writein.sum()
# Out:
# 0

# %%
list(acs_election_merged.columns)
# Out:
# ['yr_district_id',
#  'winner_votes',
#  'totalvotes',
#  'year_x',
#  'state',
#  'winner',
#  'winner_party',
#  'writein',
#  'district_id_x',
#  'winner_voteshare',
#  'total_dem_votes',
#  'total_rep_votes',
#  'total_dem_vote_share',
#  'total_rep_vote_share',
#  'L1_winner',
#  'L2_winner',
#  'L3_winner',
#  'L4_winner',
#  'L5_winner',
#  'dL1_winner',
#  'L6_winner',
#  'L7_winner',
#  'L8_winner',
#  'L9_winner',
#  'L10_winner',
#  'incumbent_in_race',
#  'incumbent_party',
#  'dL2_winner',
#  'dL3_winner',
#  'dL4_winner',
#  'dL5_winner',
#  'dL6_winner',
#  'dL7_winner',
#  'dL8_winner',
#  'dL9_winner',
#  'dL10_winner',
#  'incumbent_L5_races',
#  'incumbent_L4_races',
#  'incumbent_L3_races',
#  'incumbent_L2_races',
#  'incumbent_L10_races',
#  'rep_wins',
#  'dem_wins',
#  'rep_L5_wins',
#  'rep_L10_wins',
#  'dem_L10_wins',
#  'dem_L5_wins',
#  'rep_L4_wins',
#  'rep_L3_wins',
#  'rep_L2_wins',
#  'rep_L1_wins',
#  'dem_L4_wins',
#  'dem_L3_wins',
# ...

# %%
dropvars_model_1 = ['state',
 'winner',
 'winner_party', 'writein', 'L1_winner',
 'L2_winner',
 'L3_winner',
 'L4_winner',
 'L5_winner', 'L6_winner',
 'L7_winner',
 'L8_winner',
 'L9_winner',
 'L10_winner',
 'incumbent_party',
 'rep_wins',
 'dem_wins',
    'top_dem_candidate', 'top_rep_candidate', 'district_id_y',
 'year_y',
 'total_male',
 'male_5_to_9_years',
 'male_10_to_14_years',
 'male_15_to_17_years',
 'male_18_and_19_years',
 'male_20_years',
 'male_21_years',
 'male_22_to_24_years',
 'male_25_to_29_years',
 'male_30_to_34_years',
 'male_35_to_39_years',
 'male_40_to_44_years',
 'male_45_to_49_years',
 'male_50_to_54_years',
 'male_55_to_59_years',
 'male_60_and_61_years',
 'male_62_to_64_years',
 'male_65_and_66_years',
 'male_67_to_69_years',
 'male_70_to_74_years',
 'male_75_to_79_years',
 'male_80_to_84_years',
 'male_85_years_and_over',
 'total_female',
 'female_5_to_9_years',
 'female_10_to_14_years',
 'female_15_to_17_years',
 'female_18_and_19_years',
 'female_20_years',
 'female_21_years',
 'female_22_to_24_years',
 'female_25_to_29_years',
 'female_30_to_34_years',
 'female_35_to_39_years',
 'female_40_to_44_years',
 'female_45_to_49_years',
 'female_50_to_54_years',
 'female_55_to_59_years',
 'female_60_and_61_years',
 'female_62_to_64_years',
 'female_65_and_66_years',
 'female_67_to_69_years',
 'female_70_to_74_years',
 'female_75_to_79_years',
 'female_80_to_84_years',
 'female_85_years_and_over',
 'total_population',
 'white_alone',
 'black_or_african_american_alone',
 'american_indian_and_alaska_native',
 'asian_alone',
 'native_hawaiian_and_other_pacific',
 'some_other_race_alone',
 'two_or_more_races',
 'not_hispanic_or_latino',
 'hispanic_or_latino',
 'native',
 'native_born_in_state_of_residence',
 'native_born_in_other_state',
 'native_born_outside_the_us',
 'foreign_born',
 'population_25_and_over',
 'less_than_high_school_graduate',
 'high_school_graduate',
 'some_college_or_associate_degree',
 'bachelors_degree',
 'graduate_or_professional_degree',
 'same_house_1_year_ago',
 'moved_within_same_county',
 'moved_from_different_county',
 'moved_from_different_state',
 'moved_from_abroad',
 'workers_16_and_over',
 'public_transportation',
 'walked',
 'worked_at_home',
 'enrolled_in_school',
 'enrolled_in_college',
 'enrolled_in_school_graduate_professional',
 'population_25_and_over',
 'male_bachelors',
 'male_master',
 'male_professional_school',
 'male_doctorate',
 'female_bachelor',
 'female_master',
 'female_professional_school',
 'female_doctorate',
 'income_below_poverty',
 'total_household_income',
 'income_less_than_10000',
 'income_10000_to_14999',
 'income_15000_to_19999',
 'income_20000_to_24999',
 'income_25000_to_29999',
 'income_30000_to_34999',
 'income_35000_to_39999',
 'income_40000_to_44999',
 'income_45000_to_49999',
 'income_50000_to_59999',
 'income_60000_to_74999',
 'income_75000_to_99999',
 'income_100000_to_124999',
 'income_125000_to_149999',
 'income_150000_to_199999',
 'income_200000_or_more',
 'median_household_income',
 'income_lowest_quintile',
 'income_second_quintile',
 'income_third_quintile',
 'income_fourth_quintile',
 'income_highest_quintile',
 'income_top_5_percent',
 'veteran',
 'nonveteran',
 'population_16_and_over',
 'in_labor_force',
 'civilian_in_labor_force',
 'civilian_employed',
 'civilian_unemployed',
 'in_armed_forces',
 'total_not_in_labor_force',
 'fulltime_civilian_employed_16_and_over',
 'male_natural_resources',
 'male_production_transportation_and_material_moving',
 'female_natural_resources',
 'female_production_transportation_and_material_moving',
 'total_housing_units',
 'occupied',
 'vacant',
 'occupied_housing_units',
 'owner_occupied',
 'renter_occupied',
 'owner_occupied_housing_units',
 'housing_units_with_a_mortgage',
 'housing_units_without_a_mortgage',
 'renter_occupied_housing_units',
 'median_gross_rent',
 'total_owner_occupied_housing_units',
 'housing_value_below_10000',
 'housing_value_10000_to_14999',
 'housing_value_15000_to_19999',
 'housing_value_20000_to_24999',
 'housing_value_25000_to_29999',
 'housing_value_30000_to_34999',
 'housing_value_35000_to_39999',
 'housing_value_40000_to_49999',
 'housing_value_50000_to_59999',
 'housing_value_60000_to_69999',
 'housing_value_70000_to_79999',
 'housing_value_80000_to_89999',
 'housing_value_90000_to_99999',
 'housing_value_100000_to_124999',
 'housing_value_125000_to_149999',
 'housing_value_150000_to_174999',
 'housing_value_175000_to_199999',
 'housing_value_200000_to_249999',
 'housing_value_250000_to_299999',
 'housing_value_300000_to_399999',
 'housing_value_400000_to_499999',
 'housing_value_500000_to_749999',
 'housing_value_750000_to_999999',
 'housing_value_1000000_to_1499999',
 'median_monthly_owner_costs',
 'm75_above',
 'f75_above',
 'm60_74',
 'f60_74',
 'm45_59',
 'f45_59',
 'm30_44',
 'f30_44',
 'm18_29',
 'f18_29',
 'm18_below',
 'f18_below',
    'l1_mpop_share',
 'l2_mpop_share',
 'l1_fpop_share',
 'l2_fpop_share',
 'diff1_mpop_share',
 'diff2_mpop_share',
 'diff1_fpop_share',
 'diff2_fpop_share',
 'l1_m18_below_share',
 'l2_m18_below_share',
 'diff1_m18_below_share',
 'diff2_m18_below_share',
 'l1_f18_below_share',
 'l2_f18_below_share',
 'diff1_f18_below_share',
 'diff2_f18_below_share',
 'l1_18_below_share',
 'l2_18_below_share',
 'diff1_18_below_share',
 'diff2_18_below_share',
 'l1_m18_above',
 'l2_m18_above',
 'diff1_m18_above',
 'diff2_m18_above',
 'l1_f18_above',
 'l2_f18_above',
 'diff1_f18_above',
 'diff2_f18_above',
 'l1_18_above_share',
 'l2_18_above_share',
 'diff1_18_above_share',
 'diff2_18_above_share',
 'l1_m18_29_share',
 'l2_m18_29_share',
 'diff1_m18_29_share',
 'diff2_m18_29_share',
 'l1_f18_29_share',
 'l2_f18_29_share',
 'diff1_f18_29_share',
 'diff2_f18_29_share',
 'l1_18_29_share',
 'l2_18_29_share',
 'diff1_18_29_share',
 'diff2_18_29_share',
 'l1_m30_44_share',
 'l2_m30_44_share',
 'diff1_m30_44_share',
 'diff2_m30_44_share',
 'l1_f30_44_share',
 'l2_f30_44_share',
 'diff1_f30_44_share',
 'diff2_f30_44_share',
 'l1_30_44_share',
 'l2_30_44_share',
 'diff1_30_44_share',
 'diff2_30_44_share',
 'l1_m45_59_share',
 'l2_m45_59_share',
 'diff1_m45_59_share',
 'diff2_m45_59_share',
 'l1_f45_59_share',
 'l2_f45_59_share',
 'diff1_f45_59_share',
 'diff2_f45_59_share',
 'l1_45_59_share',
 'l2_45_59_share',
 'diff1_45_59_share',
 'diff2_45_59_share',
 'l1_m60_74_share',
 'l2_m60_74_share',
 'diff1_m60_74_share',
 'diff2_m60_74_share',
 'l1_f60_74_share',
 'l2_f60_74_share',
 'diff1_f60_74_share',
 'diff2_f60_74_share',
 'l1_60_74_share',
 'l2_60_74_share',
 'diff1_60_74_share',
 'diff2_60_74_share',
 'l1_m75_above_share',
 'l2_m75_above_share',
 'diff1_m75_above_share',
 'diff2_m75_above_share',
 'l1_f75_above_share',
 'l2_f75_above_share',
 'diff1_f75_above_share',
 'diff2_f75_above_share',
 'l1_75_above_share',
 'l2_75_above_share',
 'diff1_75_above_share',
 'diff2_75_above_share',
 'l1_white_share',
 'l2_white_share',
 'diff1_white_share',
 'diff2_white_share',
 'l1_black_share',
 'l2_black_share',
 'diff1_black_share',
 'diff2_black_share',
 'l1_asian_share',
 'l2_asian_share',
 'diff1_asian_share',
 'diff2_asian_share',
 'l1_hispanic_share',
 'l2_hispanic_share',
 'diff1_hispanic_share',
 'diff2_hispanic_share',
 'l1_otherrace_share',
 'l2_otherrace_share',
 'diff1_otherrace_share',
 'diff2_otherrace_share',
 'l1_native_share',
 'l2_native_share',
 'diff1_native_share',
 'diff2_native_share',
 'l1_nativeinstate_share',
 'l2_nativeinstate_share',
 'diff1_nativeinstate_share',
 'diff2_nativeinstate_share',
 'l1_nativeoutofstate_share',
 'l2_nativeoutofstate_share',
 'diff1_nativeoutofstate_share',
 'diff2_nativeoutofstate_share',
 'l1_foreignborn_share',
 'l2_foreignborn_share',
 'diff1_foreignborn_share',
 'diff2_foreignborn_share',
 'l1_hs_below_share',
 'l2_hs_below_share',
 'diff1_hs_below_share',
 'diff2_hs_below_share',
 'l1_hs_share',
 'l2_hs_share',
 'diff1_hs_share',
 'diff2_hs_share',
 'l1_somecollege_share',
 'l2_somecollege_share',
 'diff1_somecollege_share',
 'diff2_somecollege_share',
 'l1_college_share',
 'l2_college_share',
 'diff1_college_share',
 'diff2_college_share',
 'l1_graddeg_share',
 'l2_graddeg_share',
 'diff1_graddeg_share',
 'diff2_graddeg_share',
 'l1_samehouse_share',
 'l2_samehouse_share',
 'diff1_samehouse_share',
 'diff2_samehouse_share',
 'l1_samecounty_share',
 'l2_samecounty_share',
 'diff1_samecounty_share',
 'diff2_samecounty_share',
 'l1_samestate_share',
 'l2_samestate_share',
 'diff1_samestate_share',
 'diff2_samestate_share',
 'l1_diffstate_share',
 'l2_diffstate_share',
 'diff1_diffstate_share',
 'diff2_diffstate_share',
 'l1_liveabroad_share',
 'l2_liveabroad_share',
 'diff1_liveabroad_share',
 'diff2_liveabroad_share',
 'l1_ptransport_share',
 'l2_ptransport_share',
 'diff1_ptransport_share',
 'diff2_ptransport_share',
 'l1_walktowork_share',
 'l2_walktowork_share',
 'diff1_walktowork_share',
 'diff2_walktowork_share',
 'l1_workathome_share',
 'l2_workathome_share',
 'diff1_workathome_share',
 'diff2_workathome_share',
 'l1_inschool_share',
 'l2_inschool_share',
 'diff1_inschool_share',
 'diff2_inschool_share',
 'l1_incollege_share',
 'l2_incollege_share',
 'diff1_incollege_share',
 'diff2_incollege_share',
 'l1_ingradschool_share',
 'l2_ingradschool_share',
 'diff1_ingradschool_share',
 'diff2_ingradschool_share',
 'l1_m_college_share',
 'l2_m_college_share',
 'diff1_m_college_share',
 'diff2_m_college_share',
 'l1_m_graddeg_share',
 'l2_m_graddeg_share',
 'diff1_m_graddeg_share',
 'diff2_m_graddeg_share',
 'l1_m_phd_share',
 'l2_m_phd_share',
 'diff1_m_phd_share',
 'diff2_m_phd_share',
 'l1_f_college_share',
 'l2_f_college_share',
 'diff1_f_college_share',
 'diff2_f_college_share',
 'l1_f_graddeg_share',
 'l2_f_graddeg_share',
 'diff1_f_graddeg_share',
 'diff2_f_graddeg_share',
 'l1_f_phd_share',
 'l2_f_phd_share',
 'diff1_f_phd_share',
 'diff2_f_phd_share',
 'l1_poverty_share',
 'l2_poverty_share',
 'diff1_poverty_share',
 'diff2_poverty_share',
 'l1_hhinc_10k_less_share',
 'l2_hhinc_10k_less_share',
 'diff1_hhinc_10k_less_share',
 'diff2_hhinc_10k_less_share',
 'l1_hhinc_30k_less_share',
 'l2_hhinc_30k_less_share',
 'diff1_hhinc_30k_less_share',
 'diff2_hhinc_30k_less_share',
 'l1_hhinc_50k_less_share',
 'l2_hhinc_50k_less_share',
 'diff1_hhinc_50k_less_share',
 'diff2_hhinc_50k_less_share',
 'l1_hhinc_75k_more_share',
 'l2_hhinc_75k_more_share',
 'diff1_hhinc_75k_more_share',
 'diff2_hhinc_75k_more_share',
 'l1_hhinc_100k_more_share',
 'l2_hhinc_100k_more_share',
 'diff1_hhinc_100k_more_share',
 'diff2_hhinc_100k_more_share',
 'l1_hhinc_125k_more_share',
 'l2_hhinc_125k_more_share',
 'diff1_hhinc_125k_more_share',
 'diff2_hhinc_125k_more_share',
 'l1_hhinc_150k_more_share',
 'l2_hhinc_150k_more_share',
 'diff1_hhinc_150k_more_share',
 'diff2_hhinc_150k_more_share',
 'l1_hhinc_200k_more_share',
 'l2_hhinc_200k_more_share',
 'diff1_hhinc_200k_more_share',
 'diff2_hhinc_200k_more_share',
 'l1_veteran',
 'l2_veteran',
 'diff1_veteran',
 'diff2_veteran',
 'l1_lfpr',
 'l2_lfpr',
 'diff1_lfpr',
 'diff2_lfpr',
 'l1_unemp_rate',
 'l2_unemp_rate',
 'diff1_unemp_rate',
 'diff2_unemp_rate',
 'l1_armedforce_share',
 'l2_armedforce_share',
 'diff1_armedforce_share',
 'diff2_armedforce_share',
 'l1_naturalresourcesemp_share',
 'l2_naturalresourcesemp_share',
 'diff1_naturalresourcesemp_share',
 'diff2_naturalresourcesemp_share',
 'l1_bluecollaremp_share',
 'l2_bluecollaremp_share',
 'diff1_bluecollaremp_share',
 'diff2_bluecollaremp_share',
 'l1_vacanthousing_share',
 'l2_vacanthousing_share',
 'diff1_vacanthousing_share',
 'diff2_vacanthousing_share',
 'l1_renter_share',
 'l2_renter_share',
 'diff1_renter_share',
 'diff2_renter_share',
 'l1_mortgage_share',
 'l2_mortgage_share',
 'diff1_mortgage_share',
 'diff2_mortgage_share',
 'l1_housevalue_10k_less_share',
 'l2_housevalue_10k_less_share',
 'diff1_housevalue_10k_less_share',
 'diff2_housevalue_10k_less_share',
 'l1_housevalue_50k_less_share',
 'l2_housevalue_50k_less_share',
 'diff1_housevalue_50k_less_share',
 'diff2_housevalue_50k_less_share',
 'l1_housevalue_100k_less_share',
 'l2_housevalue_100k_less_share',
 'diff1_housevalue_100k_less_share',
 'diff2_housevalue_100k_less_share',
 'l1_housevalue_300k_more_share',
 'l2_housevalue_300k_more_share',
 'diff1_housevalue_300k_more_share',
 'diff2_housevalue_300k_more_share',
 'l1_housevalue_500k_more_share',
 'l2_housevalue_500k_more_share',
 'diff1_housevalue_500k_more_share',
 'diff2_housevalue_500k_more_share',
 'l1_housevalue_750k_more_share',
 'l2_housevalue_750k_more_share',
 'diff1_housevalue_750k_more_share',
 'diff2_housevalue_750k_more_share',
 'l1_housevalue_1m_more_share',
 'l2_housevalue_1m_more_share',
 'diff1_housevalue_1m_more_share',
 'diff2_housevalue_1m_more_share',
 'l1_median_household_income',
 'l2_median_household_income',
 'diff1_median_household_income',
 'diff2_median_household_income',
 'l1_income_lowest_quintile',
 'l2_income_lowest_quintile',
 'diff1_income_lowest_quintile',
 'diff2_income_lowest_quintile',
 'l1_income_second_quintile',
 'l2_income_second_quintile',
 'diff1_income_second_quintile',
 'diff2_income_second_quintile',
 'l1_income_third_quintile',
 'l2_income_third_quintile',
 'diff1_income_third_quintile',
 'diff2_income_third_quintile',
 'l1_income_fourth_quintile',
 'l2_income_fourth_quintile',
 'diff1_income_fourth_quintile',
 'diff2_income_fourth_quintile',
 'l1_income_highest_quintile',
 'l2_income_highest_quintile',
 'diff1_income_highest_quintile',
 'diff2_income_highest_quintile',
 'l1_income_top_5_percent',
 'l2_income_top_5_percent',
 'diff1_income_top_5_percent',
 'diff2_income_top_5_percent',
 'l1_median_gross_rent',
 'l2_median_gross_rent',
 'diff1_median_gross_rent',
 'diff2_median_gross_rent',
 'l1_median_monthly_owner_costs',
 'l2_median_monthly_owner_costs',
 'diff1_median_monthly_owner_costs',
 'diff2_median_monthly_owner_costs',
 'year_merge']

# %%
dropvars_model_2 = ['state',
 'winner',
 'winner_party', 'writein', 'L1_winner',
 'L2_winner',
 'L3_winner',
 'L4_winner',
 'L5_winner', 'L6_winner',
 'L7_winner',
 'L8_winner',
 'L9_winner',
 'L10_winner',
 'incumbent_party',
 'rep_wins',
 'dem_wins',
    'top_dem_candidate', 'top_rep_candidate', 'district_id_y',
 'year_y',
 'total_male',
 'male_5_to_9_years',
 'male_10_to_14_years',
 'male_15_to_17_years',
 'male_18_and_19_years',
 'male_20_years',
 'male_21_years',
 'male_22_to_24_years',
 'male_25_to_29_years',
 'male_30_to_34_years',
 'male_35_to_39_years',
 'male_40_to_44_years',
 'male_45_to_49_years',
 'male_50_to_54_years',
 'male_55_to_59_years',
 'male_60_and_61_years',
 'male_62_to_64_years',
 'male_65_and_66_years',
 'male_67_to_69_years',
 'male_70_to_74_years',
 'male_75_to_79_years',
 'male_80_to_84_years',
 'male_85_years_and_over',
 'total_female',
 'female_5_to_9_years',
 'female_10_to_14_years',
 'female_15_to_17_years',
 'female_18_and_19_years',
 'female_20_years',
 'female_21_years',
 'female_22_to_24_years',
 'female_25_to_29_years',
 'female_30_to_34_years',
 'female_35_to_39_years',
 'female_40_to_44_years',
 'female_45_to_49_years',
 'female_50_to_54_years',
 'female_55_to_59_years',
 'female_60_and_61_years',
 'female_62_to_64_years',
 'female_65_and_66_years',
 'female_67_to_69_years',
 'female_70_to_74_years',
 'female_75_to_79_years',
 'female_80_to_84_years',
 'female_85_years_and_over',
 'total_population',
 'white_alone',
 'black_or_african_american_alone',
 'american_indian_and_alaska_native',
 'asian_alone',
 'native_hawaiian_and_other_pacific',
 'some_other_race_alone',
 'two_or_more_races',
 'not_hispanic_or_latino',
 'hispanic_or_latino',
 'native',
 'native_born_in_state_of_residence',
 'native_born_in_other_state',
 'native_born_outside_the_us',
 'foreign_born',
 'population_25_and_over',
 'less_than_high_school_graduate',
 'high_school_graduate',
 'some_college_or_associate_degree',
 'bachelors_degree',
 'graduate_or_professional_degree',
 'same_house_1_year_ago',
 'moved_within_same_county',
 'moved_from_different_county',
 'moved_from_different_state',
 'moved_from_abroad',
 'workers_16_and_over',
 'public_transportation',
 'walked',
 'worked_at_home',
 'enrolled_in_school',
 'enrolled_in_college',
 'enrolled_in_school_graduate_professional',
 'population_25_and_over',
 'male_bachelors',
 'male_master',
 'male_professional_school',
 'male_doctorate',
 'female_bachelor',
 'female_master',
 'female_professional_school',
 'female_doctorate',
 'income_below_poverty',
 'total_household_income',
 'income_less_than_10000',
 'income_10000_to_14999',
 'income_15000_to_19999',
 'income_20000_to_24999',
 'income_25000_to_29999',
 'income_30000_to_34999',
 'income_35000_to_39999',
 'income_40000_to_44999',
 'income_45000_to_49999',
 'income_50000_to_59999',
 'income_60000_to_74999',
 'income_75000_to_99999',
 'income_100000_to_124999',
 'income_125000_to_149999',
 'income_150000_to_199999',
 'income_200000_or_more',
 'median_household_income',
 'income_lowest_quintile',
 'income_second_quintile',
 'income_third_quintile',
 'income_fourth_quintile',
 'income_highest_quintile',
 'income_top_5_percent',
 'veteran',
 'nonveteran',
 'population_16_and_over',
 'in_labor_force',
 'civilian_in_labor_force',
 'civilian_employed',
 'civilian_unemployed',
 'in_armed_forces',
 'total_not_in_labor_force',
 'fulltime_civilian_employed_16_and_over',
 'male_natural_resources',
 'male_production_transportation_and_material_moving',
 'female_natural_resources',
 'female_production_transportation_and_material_moving',
 'total_housing_units',
 'occupied',
 'vacant',
 'occupied_housing_units',
 'owner_occupied',
 'renter_occupied',
 'owner_occupied_housing_units',
 'housing_units_with_a_mortgage',
 'housing_units_without_a_mortgage',
 'renter_occupied_housing_units',
 'median_gross_rent',
 'total_owner_occupied_housing_units',
 'housing_value_below_10000',
 'housing_value_10000_to_14999',
 'housing_value_15000_to_19999',
 'housing_value_20000_to_24999',
 'housing_value_25000_to_29999',
 'housing_value_30000_to_34999',
 'housing_value_35000_to_39999',
 'housing_value_40000_to_49999',
 'housing_value_50000_to_59999',
 'housing_value_60000_to_69999',
 'housing_value_70000_to_79999',
 'housing_value_80000_to_89999',
 'housing_value_90000_to_99999',
 'housing_value_100000_to_124999',
 'housing_value_125000_to_149999',
 'housing_value_150000_to_174999',
 'housing_value_175000_to_199999',
 'housing_value_200000_to_249999',
 'housing_value_250000_to_299999',
 'housing_value_300000_to_399999',
 'housing_value_400000_to_499999',
 'housing_value_500000_to_749999',
 'housing_value_750000_to_999999',
 'housing_value_1000000_to_1499999',
 'median_monthly_owner_costs',
 'm75_above',
 'f75_above',
 'm60_74',
 'f60_74',
 'm45_59',
 'f45_59',
 'm30_44',
 'f30_44',
 'm18_29',
 'f18_29',
 'm18_below',
 'f18_below',
'l1_mpop_share',
 'l2_mpop_share',
 'l1_fpop_share',
 'l2_fpop_share',
 'diff1_mpop_share',
 'diff2_mpop_share',
 'diff1_fpop_share',
 'diff2_fpop_share',
 'l1_m18_below_share',
 'l2_m18_below_share',
 'diff1_m18_below_share',
 'diff2_m18_below_share',
 'l1_f18_below_share',
 'l2_f18_below_share',
 'diff1_f18_below_share',
 'diff2_f18_below_share',
 'l1_18_below_share',
 'l2_18_below_share',
 'diff1_18_below_share',
 'diff2_18_below_share',
 'l1_m18_above',
 'l2_m18_above',
 'diff1_m18_above',
 'diff2_m18_above',
 'l1_f18_above',
 'l2_f18_above',
 'diff1_f18_above',
 'diff2_f18_above',
 'l1_18_above_share',
 'l2_18_above_share',
 'diff1_18_above_share',
 'diff2_18_above_share',
 'l1_m18_29_share',
 'l2_m18_29_share',
 'diff1_m18_29_share',
 'diff2_m18_29_share',
 'l1_f18_29_share',
 'l2_f18_29_share',
 'diff1_f18_29_share',
 'diff2_f18_29_share',
 'l1_18_29_share',
 'l2_18_29_share',
 'diff1_18_29_share',
 'diff2_18_29_share',
 'l1_m30_44_share',
 'l2_m30_44_share',
 'diff1_m30_44_share',
 'diff2_m30_44_share',
 'l1_f30_44_share',
 'l2_f30_44_share',
 'diff1_f30_44_share',
 'diff2_f30_44_share',
 'l1_30_44_share',
 'l2_30_44_share',
 'diff1_30_44_share',
 'diff2_30_44_share',
 'l1_m45_59_share',
 'l2_m45_59_share',
 'diff1_m45_59_share',
 'diff2_m45_59_share',
 'l1_f45_59_share',
 'l2_f45_59_share',
 'diff1_f45_59_share',
 'diff2_f45_59_share',
 'l1_45_59_share',
 'l2_45_59_share',
 'diff1_45_59_share',
 'diff2_45_59_share',
 'l1_m60_74_share',
 'l2_m60_74_share',
 'diff1_m60_74_share',
 'diff2_m60_74_share',
 'l1_f60_74_share',
 'l2_f60_74_share',
 'diff1_f60_74_share',
 'diff2_f60_74_share',
 'l1_60_74_share',
 'l2_60_74_share',
 'diff1_60_74_share',
 'diff2_60_74_share',
 'l1_m75_above_share',
 'l2_m75_above_share',
 'diff1_m75_above_share',
 'diff2_m75_above_share',
 'l1_f75_above_share',
 'l2_f75_above_share',
 'diff1_f75_above_share',
 'diff2_f75_above_share',
 'l1_75_above_share',
 'l2_75_above_share',
 'diff1_75_above_share',
 'diff2_75_above_share',
 'l1_white_share',
 'l2_white_share',
 'diff1_white_share',
 'diff2_white_share',
 'l1_black_share',
 'l2_black_share',
 'diff1_black_share',
 'diff2_black_share',
 'l1_asian_share',
 'l2_asian_share',
 'diff1_asian_share',
 'diff2_asian_share',
 'l1_hispanic_share',
 'l2_hispanic_share',
 'diff1_hispanic_share',
 'diff2_hispanic_share',
 'l1_otherrace_share',
 'l2_otherrace_share',
 'diff1_otherrace_share',
 'diff2_otherrace_share',
 'l1_native_share',
 'l2_native_share',
 'diff1_native_share',
 'diff2_native_share',
 'l1_nativeinstate_share',
 'l2_nativeinstate_share',
 'diff1_nativeinstate_share',
 'diff2_nativeinstate_share',
 'l1_nativeoutofstate_share',
 'l2_nativeoutofstate_share',
 'diff1_nativeoutofstate_share',
 'diff2_nativeoutofstate_share',
 'l1_foreignborn_share',
 'l2_foreignborn_share',
 'diff1_foreignborn_share',
 'diff2_foreignborn_share',
 'l1_hs_below_share',
 'l2_hs_below_share',
 'diff1_hs_below_share',
 'diff2_hs_below_share',
 'l1_hs_share',
 'l2_hs_share',
 'diff1_hs_share',
 'diff2_hs_share',
 'l1_somecollege_share',
 'l2_somecollege_share',
 'diff1_somecollege_share',
 'diff2_somecollege_share',
 'l1_college_share',
 'l2_college_share',
 'diff1_college_share',
 'diff2_college_share',
 'l1_graddeg_share',
 'l2_graddeg_share',
 'diff1_graddeg_share',
 'diff2_graddeg_share',
 'l1_samehouse_share',
 'l2_samehouse_share',
 'diff1_samehouse_share',
 'diff2_samehouse_share',
 'l1_samecounty_share',
 'l2_samecounty_share',
 'diff1_samecounty_share',
 'diff2_samecounty_share',
 'l1_samestate_share',
 'l2_samestate_share',
 'diff1_samestate_share',
 'diff2_samestate_share',
 'l1_diffstate_share',
 'l2_diffstate_share',
 'diff1_diffstate_share',
 'diff2_diffstate_share',
 'l1_liveabroad_share',
 'l2_liveabroad_share',
 'diff1_liveabroad_share',
 'diff2_liveabroad_share',
 'l1_ptransport_share',
 'l2_ptransport_share',
 'diff1_ptransport_share',
 'diff2_ptransport_share',
 'l1_walktowork_share',
 'l2_walktowork_share',
 'diff1_walktowork_share',
 'diff2_walktowork_share',
 'l1_workathome_share',
 'l2_workathome_share',
 'diff1_workathome_share',
 'diff2_workathome_share',
 'l1_inschool_share',
 'l2_inschool_share',
 'diff1_inschool_share',
 'diff2_inschool_share',
 'l1_incollege_share',
 'l2_incollege_share',
 'diff1_incollege_share',
 'diff2_incollege_share',
 'l1_ingradschool_share',
 'l2_ingradschool_share',
 'diff1_ingradschool_share',
 'diff2_ingradschool_share',
 'l1_m_college_share',
 'l2_m_college_share',
 'diff1_m_college_share',
 'diff2_m_college_share',
 'l1_m_graddeg_share',
 'l2_m_graddeg_share',
 'diff1_m_graddeg_share',
 'diff2_m_graddeg_share',
 'l1_m_phd_share',
 'l2_m_phd_share',
 'diff1_m_phd_share',
 'diff2_m_phd_share',
 'l1_f_college_share',
 'l2_f_college_share',
 'diff1_f_college_share',
 'diff2_f_college_share',
 'l1_f_graddeg_share',
 'l2_f_graddeg_share',
 'diff1_f_graddeg_share',
 'diff2_f_graddeg_share',
 'l1_f_phd_share',
 'l2_f_phd_share',
 'diff1_f_phd_share',
 'diff2_f_phd_share',
 'l1_poverty_share',
 'l2_poverty_share',
 'diff1_poverty_share',
 'diff2_poverty_share',
 'l1_hhinc_10k_less_share',
 'l2_hhinc_10k_less_share',
 'diff1_hhinc_10k_less_share',
 'diff2_hhinc_10k_less_share',
 'l1_hhinc_30k_less_share',
 'l2_hhinc_30k_less_share',
 'diff1_hhinc_30k_less_share',
 'diff2_hhinc_30k_less_share',
 'l1_hhinc_50k_less_share',
 'l2_hhinc_50k_less_share',
 'diff1_hhinc_50k_less_share',
 'diff2_hhinc_50k_less_share',
 'l1_hhinc_75k_more_share',
 'l2_hhinc_75k_more_share',
 'diff1_hhinc_75k_more_share',
 'diff2_hhinc_75k_more_share',
 'l1_hhinc_100k_more_share',
 'l2_hhinc_100k_more_share',
 'diff1_hhinc_100k_more_share',
 'diff2_hhinc_100k_more_share',
 'l1_hhinc_125k_more_share',
 'l2_hhinc_125k_more_share',
 'diff1_hhinc_125k_more_share',
 'diff2_hhinc_125k_more_share',
 'l1_hhinc_150k_more_share',
 'l2_hhinc_150k_more_share',
 'diff1_hhinc_150k_more_share',
 'diff2_hhinc_150k_more_share',
 'l1_hhinc_200k_more_share',
 'l2_hhinc_200k_more_share',
 'diff1_hhinc_200k_more_share',
 'diff2_hhinc_200k_more_share',
 'l1_veteran',
 'l2_veteran',
 'diff1_veteran',
 'diff2_veteran',
 'l1_lfpr',
 'l2_lfpr',
 'diff1_lfpr',
 'diff2_lfpr',
 'l1_unemp_rate',
 'l2_unemp_rate',
 'diff1_unemp_rate',
 'diff2_unemp_rate',
 'l1_armedforce_share',
 'l2_armedforce_share',
 'diff1_armedforce_share',
 'diff2_armedforce_share',
 'l1_naturalresourcesemp_share',
 'l2_naturalresourcesemp_share',
 'diff1_naturalresourcesemp_share',
 'diff2_naturalresourcesemp_share',
 'l1_bluecollaremp_share',
 'l2_bluecollaremp_share',
 'diff1_bluecollaremp_share',
 'diff2_bluecollaremp_share',
 'l1_vacanthousing_share',
 'l2_vacanthousing_share',
 'diff1_vacanthousing_share',
 'diff2_vacanthousing_share',
 'l1_renter_share',
 'l2_renter_share',
 'diff1_renter_share',
 'diff2_renter_share',
 'l1_mortgage_share',
 'l2_mortgage_share',
 'diff1_mortgage_share',
 'diff2_mortgage_share',
 'l1_housevalue_10k_less_share',
 'l2_housevalue_10k_less_share',
 'diff1_housevalue_10k_less_share',
 'diff2_housevalue_10k_less_share',
 'l1_housevalue_50k_less_share',
 'l2_housevalue_50k_less_share',
 'diff1_housevalue_50k_less_share',
 'diff2_housevalue_50k_less_share',
 'l1_housevalue_100k_less_share',
 'l2_housevalue_100k_less_share',
 'diff1_housevalue_100k_less_share',
 'diff2_housevalue_100k_less_share',
 'l1_housevalue_300k_more_share',
 'l2_housevalue_300k_more_share',
 'diff1_housevalue_300k_more_share',
 'diff2_housevalue_300k_more_share',
 'l1_housevalue_500k_more_share',
 'l2_housevalue_500k_more_share',
 'diff1_housevalue_500k_more_share',
 'diff2_housevalue_500k_more_share',
 'l1_housevalue_750k_more_share',
 'l2_housevalue_750k_more_share',
 'diff1_housevalue_750k_more_share',
 'diff2_housevalue_750k_more_share',
 'l1_housevalue_1m_more_share',
 'l2_housevalue_1m_more_share',
 'diff1_housevalue_1m_more_share',
 'diff2_housevalue_1m_more_share',
 'l1_median_household_income',
 'l2_median_household_income',
 'diff1_median_household_income',
 'diff2_median_household_income',
 'l1_income_lowest_quintile',
 'l2_income_lowest_quintile',
 'diff1_income_lowest_quintile',
 'diff2_income_lowest_quintile',
 'l1_income_second_quintile',
 'l2_income_second_quintile',
 'diff1_income_second_quintile',
 'diff2_income_second_quintile',
 'l1_income_third_quintile',
 'l2_income_third_quintile',
 'diff1_income_third_quintile',
 'diff2_income_third_quintile',
 'l1_income_fourth_quintile',
 'l2_income_fourth_quintile',
 'diff1_income_fourth_quintile',
 'diff2_income_fourth_quintile',
 'l1_income_highest_quintile',
 'l2_income_highest_quintile',
 'diff1_income_highest_quintile',
 'diff2_income_highest_quintile',
 'l1_income_top_5_percent',
 'l2_income_top_5_percent',
 'diff1_income_top_5_percent',
 'diff2_income_top_5_percent',
 'l1_median_gross_rent',
 'l2_median_gross_rent',
 'diff1_median_gross_rent',
 'diff2_median_gross_rent',
 'l1_median_monthly_owner_costs',
 'l2_median_monthly_owner_costs',
 'diff1_median_monthly_owner_costs',
 'diff2_median_monthly_owner_costs',
 'year_merge']

# %%
len(dropvars_model_2)
# Out:
# 550

# %%
regex = re.compile(r'^l1', re.UNICODE)
l1_to_drop = set(list(filter(regex.search, dropvars_model_2)))

# %%
regex2 = re.compile(r'^diff1', re.UNICODE)
diff1_to_drop = set(list(filter(regex2.search, dropvars_model_2)))

# %%
len(set(dropvars_model_2))
# Out:
# 549

# %%
len(l1_to_drop)
# Out:
# 88

# %%
len(diff1_to_drop)
# Out:
# 88

# %%
dropvars_model_2 = set(dropvars_model_2) - l1_to_drop - diff1_to_drop
len(dropvars_model_2)
# Out:
# 373

# %%
acs_election_merged_model_2 = acs_election_merged.drop(dropvars_model_2, axis = 1)

# %%
districts_to_drop = ['AZ-09', 'FL-26', 'FL-27', 'GA-14', 'NV-04',
                     'SC-07', 'TX-33', 'TX-34', 'TX-35', 'TX-36', 'UT-04', 'WA-10']

# %%
acs_election_merged_model_2 = acs_election_merged_model_2[acs_election_merged_model_2.district_id_x.isin(districts_to_drop) == False]

# %% [markdown]
# Save to `.csv`

# %%
acs_election_merged_model_2.to_csv('../../data/02_intermediate/ACS_HouseVotes_merged_L1_years.csv', index=False)

# %% [markdown]
# ## Next Steps
#
# - Drop redundant columns (district_id_x, year_x, etc.)
# - Drop duplicative ACS/house vote columns
# - Save final processed .csv to `data/03_processed/`
